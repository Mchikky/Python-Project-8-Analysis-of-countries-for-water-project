# %%
#importation des pandas librairies
import pandas as pd
import os
#os.chdir(r"D:\PRO\Missions\OpenClassrooms\Data analyst\P5\Matériel")

# %%
os.getcwd()
# Out:
# '/Users/chikaodilideng/Project 8'

# %%
#importation de fichier CSV

region_country = pd.read_csv('RegionCountry.csv')
population = pd.read_csv("Population.csv")
political_stability = pd.read_csv("PoliticalStability.csv")
mortality_rate = pd.read_csv("MortalityRateAttributedToWater.csv")
basic_safewaterserv = pd.read_csv("BasicAndSafelyManagedDrinkingWaterServices.csv")

# %%
region_country.to_csv('acss.csv')

# %%
#Afficher les 5 premières lignes du data frame pour vérifier que les données sont bien chargées.
region_country.head()
# Out:
#   REGION (DISPLAY) COUNTRY (DISPLAY)
# 0           Europe           Albania
# 1           Europe           Andorra
# 2           Europe           Armenia
# 3  Western Pacific         Australia
# 4           Europe           Austria

# %%
#Afficher les 5 dernières lignes du data frame pour vérifier que les données sont bien chargées.
region_country.tail()
# Out:
#           REGION (DISPLAY)                   COUNTRY (DISPLAY)
# 189  Eastern Mediterranean                United Arab Emirates
# 190               Americas  Venezuela (Bolivarian Republic of)
# 191        Western Pacific                            Viet Nam
# 192  Eastern Mediterranean                               Yemen
# 193                 Africa                            Zimbabwe

# %%
#vérifier l'ensemble de données importées
region_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   REGION (DISPLAY)   194 non-null    object
#  1   COUNTRY (DISPLAY)  194 non-null    object
# dtypes: object(2)
# memory usage: 3.2+ KB

# %%
#Faire des statistiques 
region_country.describe(include="all")
# Out:
#        REGION (DISPLAY) COUNTRY (DISPLAY)
# count               194               194
# unique                6               194
# top              Europe           Albania
# freq                 53                 1

# %%
#Vérifier des valeurs manquantes
region_country.isna().sum()
# Out:
# REGION (DISPLAY)     0
# COUNTRY (DISPLAY)    0
# dtype: int64

# %%
#Déterminer les types de données
region_country.dtypes
# Out:
# REGION (DISPLAY)     object
# COUNTRY (DISPLAY)    object
# dtype: object

# %%
#Vérifier des doublons dans le dataframe
region_country.duplicated().sum()
# Out:
# 0

# %%
#Vérifier des valeurs manquantes dans la colonne "client_id"
region_country["COUNTRY (DISPLAY)"].isna().sum()
# Out:
# 0

# %%
#Vérifier des doublons dans la colonne "client_id"
region_country["COUNTRY (DISPLAY)"].duplicated().sum()
# Out:
# 0

# %%
#lister des nombres de valeurs différentes au sein de dataframe customers
region_country.nunique()
# Out:
# REGION (DISPLAY)       6
# COUNTRY (DISPLAY)    194
# dtype: int64

# %%
#renommer les colonnes de deux data frames
region_country.rename(columns={"REGION (DISPLAY)":"Region","COUNTRY (DISPLAY)":"Country"},inplace=True)

# %%
reg = region_country.set_index(['Region','Country'])
reg
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
#Afficher les 5 premières lignes du data frame pour vérifier que les données sont bien chargées.
population.head()
# Out:
#        Country Granularity  Year  Population
# 0  Afghanistan       Total  2000   20779.953
# 1  Afghanistan        Male  2000   10689.508
# 2  Afghanistan      Female  2000   10090.449
# 3  Afghanistan       Rural  2000   15657.474
# 4  Afghanistan       Urban  2000    4436.282

# %%
#Afficher les 5 dernières lignes du data frame pour vérifier que les données sont bien chargées.
population.tail()
# Out:
#         Country Granularity  Year  Population
# 20909  Zimbabwe       Total  2018   14438.802
# 20910  Zimbabwe        Male  2018    6879.119
# 20911  Zimbabwe      Female  2018    7559.693
# 20912  Zimbabwe       Rural  2018   11465.748
# 20913  Zimbabwe       Urban  2018    5447.513

# %%
#Vérifier des valeurs manquantes
population.isna().sum()
# Out:
# Country        0
# Granularity    0
# Year           0
# Population     0
# dtype: int64

# %%
population.describe(include="all")
# Out:
#             Country Granularity          Year    Population
# count         20914       20914  20914.000000  2.091400e+04
# unique          239           5           NaN           NaN
# top     Afghanistan       Total           NaN           NaN
# freq             95        4430           NaN           NaN
# mean            NaN         NaN   2009.046715  2.253164e+04
# std             NaN         NaN      5.479195  1.000169e+05
# min             NaN         NaN   2000.000000  0.000000e+00
# 25%             NaN         NaN   2004.000000  3.483462e+02
# 50%             NaN         NaN   2009.000000  3.016337e+03
# 75%             NaN         NaN   2014.000000  1.115043e+04
# max             NaN         NaN   2018.000000  1.459378e+06

# %%
population["Population"]=pd.to_numeric(population["Population"], errors='coerce')

# %%
#Remplacer des valeurs manquantes NaN, avec 0
population.fillna(0,inplace=True)
population.describe()
# Out:
#                Year    Population
# count  20914.000000  2.091400e+04
# mean    2009.046715  2.253164e+04
# std        5.479195  1.000169e+05
# min     2000.000000  0.000000e+00
# 25%     2004.000000  3.483462e+02
# 50%     2009.000000  3.016337e+03
# 75%     2014.000000  1.115043e+04
# max     2018.000000  1.459378e+06

# %%
#Vérifier les types de données dans les colonnes et compter des valeurs non manquantes
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20914 entries, 0 to 20913
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      20914 non-null  object
#  1   Granularity  20914 non-null  object
#  2   Year         20914 non-null  int64
#  3   Population   20914 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 653.7+ KB

# %%
#Vérifier des doublons dans le dataframe population
population.duplicated().sum()
# Out:
# 0

# %%
#Vérifier des doublons dans la colonne "Country"
population["Country"].duplicated().sum()
# Out:
# 20675

# %%
#Vérifier des valeurs manquantes dans la colonnes "Country"
population["Country"].isna().sum()
# Out:
# 0

# %%
#Compter des nombres de valeurs différentes dans le dataframe population
population.nunique()
# Out:
# Country          239
# Granularity        5
# Year              19
# Population     20515
# dtype: int64

# %%
#Lister des valeurs différentes au sein de colonne "Country"
population["Country"].nunique()
# Out:
# 239

# %%
population["Country"].duplicated().sum()
# Out:
# 20675

# %%
#Convertir NaN au 0
population["Population"]=pd.to_numeric(population["Population"], errors='coerce')
population.fillna(0,inplace=True)
#Multiplier par 1000 car la population est exprimée en milliers d'habitants
population["Population"]*=1000

# %%
option=['Total']
pop_annee_total =population[population['Granularity'].isin(option)]
pop_annee_total
# Out:
#            Country Granularity  Year  Population
# 0      Afghanistan       Total  2000  20779953.0
# 5      Afghanistan       Total  2001  21606988.0
# 10     Afghanistan       Total  2002  22600770.0
# 15     Afghanistan       Total  2003  23680871.0
# 20     Afghanistan       Total  2004  24726684.0
# ...            ...         ...   ...         ...
# 20889     Zimbabwe       Total  2014  13586707.0
# 20894     Zimbabwe       Total  2015  13814629.0
# 20899     Zimbabwe       Total  2016  14030331.0
# 20904     Zimbabwe       Total  2017  14236595.0
# 20909     Zimbabwe       Total  2018  14438802.0
#
# [4430 rows x 4 columns]

# %%
pop_annee_total.to_csv('pop_annee_total.csv')

# %%
pop_annee_total[pop_annee_total['Year']==2018]
# Out:
#                          Country Granularity  Year  Population
# 90                   Afghanistan       Total  2018  37171921.0
# 185                      Albania       Total  2018   2882740.0
# 280                      Algeria       Total  2018  42228408.0
# 339               American Samoa       Total  2018     55465.0
# 396                      Andorra       Total  2018     77006.0
# ...                          ...         ...   ...         ...
# 20531  Wallis and Futuna Islands       Total  2018     11661.0
# 20624             Western Sahara       Total  2018    567402.0
# 20719                      Yemen       Total  2018  28498683.0
# 20814                     Zambia       Total  2018  17351708.0
# 20909                   Zimbabwe       Total  2018  14438802.0
#
# [237 rows x 4 columns]

# %%
chad_pop_density = pop_annee_total[pop_annee_total['Country']=='Chad'].copy()
chad_pop_density
# Out:
#      Country Granularity  Year  Population
# 3501    Chad       Total  2000   8355654.0
# 3506    Chad       Total  2001   8678051.0
# 3511    Chad       Total  2002   9019233.0
# 3516    Chad       Total  2003   9373916.0
# 3521    Chad       Total  2004   9734767.0
# 3526    Chad       Total  2005  10096633.0
# 3531    Chad       Total  2006  10457124.0
# 3536    Chad       Total  2007  10818024.0
# 3541    Chad       Total  2008  11183588.0
# 3546    Chad       Total  2009  11560147.0
# 3551    Chad       Total  2010  11952136.0
# 3556    Chad       Total  2011  12360990.0
# 3561    Chad       Total  2012  12784750.0
# 3566    Chad       Total  2013  13220433.0
# 3571    Chad       Total  2014  13663566.0
# 3576    Chad       Total  2015  14110975.0
# 3581    Chad       Total  2016  14561660.0
# 3586    Chad       Total  2017  15016753.0
# 3591    Chad       Total  2018  15477729.0

# %%
chad_pop_density['Population density (per km2)']= (chad_pop_density['Population']/1259200)

# %%
chad_pop_density
# Out:
#      Country Granularity  Year  Population  Population density (per km2)
# 3501    Chad       Total  2000   8355654.0                      6.635685
# 3506    Chad       Total  2001   8678051.0                      6.891718
# 3511    Chad       Total  2002   9019233.0                      7.162669
# 3516    Chad       Total  2003   9373916.0                      7.444342
# 3521    Chad       Total  2004   9734767.0                      7.730914
# 3526    Chad       Total  2005  10096633.0                      8.018292
# 3531    Chad       Total  2006  10457124.0                      8.304578
# 3536    Chad       Total  2007  10818024.0                      8.591188
# 3541    Chad       Total  2008  11183588.0                      8.881503
# 3546    Chad       Total  2009  11560147.0                      9.180549
# 3551    Chad       Total  2010  11952136.0                      9.491849
# 3556    Chad       Total  2011  12360990.0                      9.816542
# ...

# %%
chad_pop_density.to_csv('chad_pop_density.csv')

# %%
options=['Urban','Rural']
pop_urban_rural =population[population['Granularity'].isin(options)]
pop_urban_rural
# Out:
#            Country Granularity  Year  Population
# 3      Afghanistan       Rural  2000  15657474.0
# 4      Afghanistan       Urban  2000   4436282.0
# 8      Afghanistan       Rural  2001  16318324.0
# 9      Afghanistan       Urban  2001   4648139.0
# 13     Afghanistan       Rural  2002  17086910.0
# ...            ...         ...   ...         ...
# 20903     Zimbabwe       Urban  2016   5215894.0
# 20907     Zimbabwe       Rural  2017  11201138.0
# 20908     Zimbabwe       Urban  2017   5328766.0
# 20912     Zimbabwe       Rural  2018  11465748.0
# 20913     Zimbabwe       Urban  2018   5447513.0
#
# [8828 rows x 4 columns]

# %%
options=['Urban']
pop_annee_urban =population[population['Granularity'].isin(options)]
pop_annee_urban
# Out:
#            Country Granularity  Year  Population
# 4      Afghanistan       Urban  2000   4436282.0
# 9      Afghanistan       Urban  2001   4648139.0
# 14     Afghanistan       Urban  2002   4893013.0
# 19     Afghanistan       Urban  2003   5155788.0
# 24     Afghanistan       Urban  2004   5426872.0
# ...            ...         ...   ...         ...
# 20893     Zimbabwe       Urban  2014   5009401.0
# 20898     Zimbabwe       Urban  2015   5109485.0
# 20903     Zimbabwe       Urban  2016   5215894.0
# 20908     Zimbabwe       Urban  2017   5328766.0
# 20913     Zimbabwe       Urban  2018   5447513.0
#
# [4414 rows x 4 columns]

# %%
options=['Rural']
pop_annee_rural =population[population['Granularity'].isin(options)]
pop_annee_rural
# Out:
#            Country Granularity  Year  Population
# 3      Afghanistan       Rural  2000  15657474.0
# 8      Afghanistan       Rural  2001  16318324.0
# 13     Afghanistan       Rural  2002  17086910.0
# 18     Afghanistan       Rural  2003  17909063.0
# 23     Afghanistan       Rural  2004  18692107.0
# ...            ...         ...   ...         ...
# 20892     Zimbabwe       Rural  2014  10402274.0
# 20897     Zimbabwe       Rural  2015  10667966.0
# 20902     Zimbabwe       Rural  2016  10934468.0
# 20907     Zimbabwe       Rural  2017  11201138.0
# 20912     Zimbabwe       Rural  2018  11465748.0
#
# [4414 rows x 4 columns]

# %%
pop_annee_UR=pd.merge(pop_annee_urban,pop_annee_rural,on=['Country', 'Year'], how='inner')
pop_annee_UR
# Out:
#           Country Granularity_x  Year  Population_x Granularity_y  \
# 0     Afghanistan         Urban  2000     4436282.0         Rural
# 1     Afghanistan         Urban  2001     4648139.0         Rural
# 2     Afghanistan         Urban  2002     4893013.0         Rural
# 3     Afghanistan         Urban  2003     5155788.0         Rural
# 4     Afghanistan         Urban  2004     5426872.0         Rural
# ...           ...           ...   ...           ...           ...
# 4409     Zimbabwe         Urban  2014     5009401.0         Rural
# 4410     Zimbabwe         Urban  2015     5109485.0         Rural
# 4411     Zimbabwe         Urban  2016     5215894.0         Rural
# 4412     Zimbabwe         Urban  2017     5328766.0         Rural
# 4413     Zimbabwe         Urban  2018     5447513.0         Rural
#
#       Population_y
# 0       15657474.0
# 1       16318324.0
# 2       17086910.0
# 3       17909063.0
# 4       18692107.0
# ...            ...
# 4409    10402274.0
# ...

# %%
pop_annee_UR.rename(columns={'Granularity_x':'Urban','Population_x':'Pop_urban','Granularity_y':'Rural','Population_y':'Pop_rural'},inplace=True)
pop_annee_UR
# Out:
#           Country  Urban  Year  Pop_urban  Rural   Pop_rural
# 0     Afghanistan  Urban  2000  4436282.0  Rural  15657474.0
# 1     Afghanistan  Urban  2001  4648139.0  Rural  16318324.0
# 2     Afghanistan  Urban  2002  4893013.0  Rural  17086910.0
# 3     Afghanistan  Urban  2003  5155788.0  Rural  17909063.0
# 4     Afghanistan  Urban  2004  5426872.0  Rural  18692107.0
# ...           ...    ...   ...        ...    ...         ...
# 4409     Zimbabwe  Urban  2014  5009401.0  Rural  10402274.0
# 4410     Zimbabwe  Urban  2015  5109485.0  Rural  10667966.0
# 4411     Zimbabwe  Urban  2016  5215894.0  Rural  10934468.0
# 4412     Zimbabwe  Urban  2017  5328766.0  Rural  11201138.0
# 4413     Zimbabwe  Urban  2018  5447513.0  Rural  11465748.0
#
# [4414 rows x 6 columns]

# %%
pop_annee_UR['ratio'] =round(pop_annee_UR ['Pop_urban']/pop_annee_UR['Pop_rural'],2)

# %%
pop_annee_UR
# Out:
#           Country  Urban  Year  Pop_urban  Rural   Pop_rural  ratio
# 0     Afghanistan  Urban  2000  4436282.0  Rural  15657474.0   0.28
# 1     Afghanistan  Urban  2001  4648139.0  Rural  16318324.0   0.28
# 2     Afghanistan  Urban  2002  4893013.0  Rural  17086910.0   0.29
# 3     Afghanistan  Urban  2003  5155788.0  Rural  17909063.0   0.29
# 4     Afghanistan  Urban  2004  5426872.0  Rural  18692107.0   0.29
# ...           ...    ...   ...        ...    ...         ...    ...
# 4409     Zimbabwe  Urban  2014  5009401.0  Rural  10402274.0   0.48
# 4410     Zimbabwe  Urban  2015  5109485.0  Rural  10667966.0   0.48
# 4411     Zimbabwe  Urban  2016  5215894.0  Rural  10934468.0   0.48
# 4412     Zimbabwe  Urban  2017  5328766.0  Rural  11201138.0   0.48
# 4413     Zimbabwe  Urban  2018  5447513.0  Rural  11465748.0   0.48
#
# [4414 rows x 7 columns]

# %%
options=["Kuwait",'Qatar']
kuwait_qatar =pop_annee_UR[pop_annee_UR['Country'].isin(options)]
kuwait_qatar
# Out:
#      Country  Urban  Year  Pop_urban  Rural  Pop_rural    ratio
# 2144  Kuwait  Urban  2000  2030234.0  Rural    20507.0    99.00
# 2145  Kuwait  Urban  2001  2107417.0  Rural     1938.0  1087.42
# 2146  Kuwait  Urban  2002  2143833.0  Rural        0.0      inf
# 2147  Kuwait  Urban  2003  2169118.0  Rural        0.0      inf
# 2148  Kuwait  Urban  2004  2207939.0  Rural        0.0      inf
# 2149  Kuwait  Urban  2005  2276623.0  Rural        0.0      inf
# 2150  Kuwait  Urban  2006  2377258.0  Rural        0.0      inf
# 2151  Kuwait  Urban  2007  2503410.0  Rural        0.0      inf
# 2152  Kuwait  Urban  2008  2652340.0  Rural        0.0      inf
# 2153  Kuwait  Urban  2009  2818939.0  Rural        0.0      inf
# 2154  Kuwait  Urban  2010  2998083.0  Rural        0.0      inf
# 2155  Kuwait  Urban  2011  3191051.0  Rural        0.0      inf
# 2156  Kuwait  Urban  2012  3395556.0  Rural        0.0      inf
# 2157  Kuwait  Urban  2013  3598385.0  Rural        0.0      inf
# ...

# %%
pop_annee_UR.to_csv('pop_annee_UR.csv')

# %%
pop_2017 = pop_urban_rural[pop_urban_rural['Year']==2017]
pop_2017
# Out:
#            Country Granularity  Year  Population
# 88     Afghanistan       Rural  2017  26558609.0
# 89     Afghanistan       Urban  2017   8971472.0
# 183        Albania       Rural  2017   1190155.0
# 184        Albania       Urban  2017   1740032.0
# 278        Algeria       Rural  2017  11547532.0
# ...            ...         ...   ...         ...
# 20718        Yemen       Urban  2017  10174612.0
# 20812       Zambia       Rural  2017   9747709.0
# 20813       Zambia       Urban  2017   7346421.0
# 20907     Zimbabwe       Rural  2017  11201138.0
# 20908     Zimbabwe       Urban  2017   5328766.0
#
# [470 rows x 4 columns]

# %%
pop2017_urban_rural = pd.merge(region_country,pop_urban_rural[pop_urban_rural['Year']==2017], on ='Country',how ='left')
pop2017_urban_rural
# Out:
#                     Region   Country Granularity    Year  Population
# 0                   Europe   Albania       Rural  2017.0   1190155.0
# 1                   Europe   Albania       Urban  2017.0   1740032.0
# 2                   Europe   Andorra       Rural  2017.0      9120.0
# 3                   Europe   Andorra       Urban  2017.0     67845.0
# 4                   Europe   Armenia       Rural  2017.0   1081248.0
# ..                     ...       ...         ...     ...         ...
# 382        Western Pacific  Viet Nam       Urban  2017.0  33642498.0
# 383  Eastern Mediterranean     Yemen       Rural  2017.0  18075808.0
# 384  Eastern Mediterranean     Yemen       Urban  2017.0  10174612.0
# 385                 Africa  Zimbabwe       Rural  2017.0  11201138.0
# 386                 Africa  Zimbabwe       Urban  2017.0   5328766.0
#
# [387 rows x 5 columns]

# %%
pop2017_urban = pop2017_urban_rural[pop2017_urban_rural['Granularity']=='Urban']
pop2017_urban
# Out:
#                     Region                             Country Granularity  \
# 1                   Europe                             Albania       Urban
# 3                   Europe                             Andorra       Urban
# 5                   Europe                             Armenia       Urban
# 7          Western Pacific                           Australia       Urban
# 9                   Europe                             Austria       Urban
# ..                     ...                                 ...         ...
# 378  Eastern Mediterranean                United Arab Emirates       Urban
# 380               Americas  Venezuela (Bolivarian Republic of)       Urban
# 382        Western Pacific                            Viet Nam       Urban
# 384  Eastern Mediterranean                               Yemen       Urban
# 386                 Africa                            Zimbabwe       Urban
#
#        Year  Population
# 1    2017.0   1740032.0
# ...

# %%
pop2017_urban = pd.merge(pop_2017,pop2017_urban[pop2017_urban['Year']==2017], on ='Country',how ='left')
pop2017_urban
# Out:
#          Country Granularity_x  Year_x  Population_x                 Region  \
# 0    Afghanistan         Rural    2017    26558609.0  Eastern Mediterranean
# 1    Afghanistan         Urban    2017     8971472.0  Eastern Mediterranean
# 2        Albania         Rural    2017     1190155.0                 Europe
# 3        Albania         Urban    2017     1740032.0                 Europe
# 4        Algeria         Rural    2017    11547532.0                 Africa
# ..           ...           ...     ...           ...                    ...
# 465        Yemen         Urban    2017    10174612.0  Eastern Mediterranean
# 466       Zambia         Rural    2017     9747709.0                 Africa
# 467       Zambia         Urban    2017     7346421.0                 Africa
# 468     Zimbabwe         Rural    2017    11201138.0                 Africa
# 469     Zimbabwe         Urban    2017     5328766.0                 Africa
#
#     Granularity_y  Year_y  Population_y
# ...

# %%
pop2017_urban.drop(['Year_x','Year_y','Granularity_x','Granularity_y'],axis=1,inplace=True)

# %%
pop2017_urban.rename(columns={'Population_x':'Pop_2017_total','Population_y':'Pop_2017_urban'},inplace=True)

# %%
#Remplacer des valeurs manquantes NaN, avec 0
pop2017_urban.fillna(0,inplace=True)
pop2017_urban.head()
# Out:
#        Country  Pop_2017_total                 Region  Pop_2017_urban
# 0  Afghanistan      26558609.0  Eastern Mediterranean       8971472.0
# 1  Afghanistan       8971472.0  Eastern Mediterranean       8971472.0
# 2      Albania       1190155.0                 Europe       1740032.0
# 3      Albania       1740032.0                 Europe       1740032.0
# 4      Algeria      11547532.0                 Africa      29770610.0

# %%
#Identifier la colonne à déplacer
column_to_move = pop2017_urban.pop("Region")
#Insérer une colonne avec insert(location, column_name, column_value)
pop2017_urban.insert(0, "Region", column_to_move )

# %%
pop2017_urban.head()
# Out:
#                   Region      Country  Pop_2017_total  Pop_2017_urban
# 0  Eastern Mediterranean  Afghanistan      26558609.0       8971472.0
# 1  Eastern Mediterranean  Afghanistan       8971472.0       8971472.0
# 2                 Europe      Albania       1190155.0       1740032.0
# 3                 Europe      Albania       1740032.0       1740032.0
# 4                 Africa      Algeria      11547532.0      29770610.0

# %%
#Insérer une colonne
pop2017_urban["taux_pop_urbaine(%)"]= round((pop2017_urban['Pop_2017_urban']/pop2017_urban['Pop_2017_total'])*100,2)
pop2017_urban
# Out:
#                     Region      Country  Pop_2017_total  Pop_2017_urban  \
# 0    Eastern Mediterranean  Afghanistan      26558609.0       8971472.0
# 1    Eastern Mediterranean  Afghanistan       8971472.0       8971472.0
# 2                   Europe      Albania       1190155.0       1740032.0
# 3                   Europe      Albania       1740032.0       1740032.0
# 4                   Africa      Algeria      11547532.0      29770610.0
# ..                     ...          ...             ...             ...
# 465  Eastern Mediterranean        Yemen      10174612.0      10174612.0
# 466                 Africa       Zambia       9747709.0       7346421.0
# 467                 Africa       Zambia       7346421.0       7346421.0
# 468                 Africa     Zimbabwe      11201138.0       5328766.0
# 469                 Africa     Zimbabwe       5328766.0       5328766.0
#
#      taux_pop_urbaine(%)
# 0                  33.78
# 1                 100.00
# ...

# %%
pop2017_urban.to_csv('pop2017_urban.csv')

# %%
population
# Out:
#            Country Granularity  Year  Population
# 0      Afghanistan       Total  2000  20779953.0
# 1      Afghanistan        Male  2000  10689508.0
# 2      Afghanistan      Female  2000  10090449.0
# 3      Afghanistan       Rural  2000  15657474.0
# 4      Afghanistan       Urban  2000   4436282.0
# ...            ...         ...   ...         ...
# 20909     Zimbabwe       Total  2018  14438802.0
# 20910     Zimbabwe        Male  2018   6879119.0
# 20911     Zimbabwe      Female  2018   7559693.0
# 20912     Zimbabwe       Rural  2018  11465748.0
# 20913     Zimbabwe       Urban  2018   5447513.0
#
# [20914 rows x 4 columns]

# %%
options=['Male','Female']
pop_male_female =population[population['Granularity'].isin(options)]
pop_male_female
# Out:
#            Country Granularity  Year  Population
# 1      Afghanistan        Male  2000  10689508.0
# 2      Afghanistan      Female  2000  10090449.0
# 6      Afghanistan        Male  2001  11117754.0
# 7      Afghanistan      Female  2001  10489238.0
# 11     Afghanistan        Male  2002  11642106.0
# ...            ...         ...   ...         ...
# 20901     Zimbabwe      Female  2016   7356132.0
# 20905     Zimbabwe        Male  2017   6777054.0
# 20906     Zimbabwe      Female  2017   7459545.0
# 20910     Zimbabwe        Male  2018   6879119.0
# 20911     Zimbabwe      Female  2018   7559693.0
#
# [7656 rows x 4 columns]

# %%
pop_2018 = pop_male_female[pop_male_female['Year']==2018]
pop_2018
# Out:
#            Country Granularity  Year  Population
# 91     Afghanistan        Male  2018  19093043.0
# 92     Afghanistan      Female  2018  18078879.0
# 186        Albania        Male  2018   1468376.0
# 187        Albania      Female  2018   1414359.0
# 281        Algeria        Male  2018  21331993.0
# ...            ...         ...   ...         ...
# 20721        Yemen      Female  2018  14138669.0
# 20815       Zambia        Male  2018   8590277.0
# 20816       Zambia      Female  2018   8761437.0
# 20910     Zimbabwe        Male  2018   6879119.0
# 20911     Zimbabwe      Female  2018   7559693.0
#
# [406 rows x 4 columns]

# %%
reg_pop = pd.merge(region_country,pop_male_female[pop_male_female['Year']==2018], on ='Country',how ='left')
reg_pop
# Out:
#                     Region   Country Granularity    Year  Population
# 0                   Europe   Albania        Male  2018.0   1468376.0
# 1                   Europe   Albania      Female  2018.0   1414359.0
# 2                   Europe   Andorra         NaN     NaN         NaN
# 3                   Europe   Armenia        Male  2018.0   1388600.0
# 4                   Europe   Armenia      Female  2018.0   1563141.0
# ..                     ...       ...         ...     ...         ...
# 371        Western Pacific  Viet Nam      Female  2018.0  47865095.0
# 372  Eastern Mediterranean     Yemen        Male  2018.0  14360014.0
# 373  Eastern Mediterranean     Yemen      Female  2018.0  14138669.0
# 374                 Africa  Zimbabwe        Male  2018.0   6879119.0
# 375                 Africa  Zimbabwe      Female  2018.0   7559693.0
#
# [376 rows x 5 columns]

# %%
options=['Total']
df_poptotal=population[population['Granularity'].isin(options)]
df_poptotal
# Out:
#            Country Granularity  Year  Population
# 0      Afghanistan       Total  2000  20779953.0
# 5      Afghanistan       Total  2001  21606988.0
# 10     Afghanistan       Total  2002  22600770.0
# 15     Afghanistan       Total  2003  23680871.0
# 20     Afghanistan       Total  2004  24726684.0
# ...            ...         ...   ...         ...
# 20889     Zimbabwe       Total  2014  13586707.0
# 20894     Zimbabwe       Total  2015  13814629.0
# 20899     Zimbabwe       Total  2016  14030331.0
# 20904     Zimbabwe       Total  2017  14236595.0
# 20909     Zimbabwe       Total  2018  14438802.0
#
# [4430 rows x 4 columns]

# %%
pop_total = population[population['Granularity']=='Total']
pop_total
# Out:
#            Country Granularity  Year  Population
# 0      Afghanistan       Total  2000  20779953.0
# 5      Afghanistan       Total  2001  21606988.0
# 10     Afghanistan       Total  2002  22600770.0
# 15     Afghanistan       Total  2003  23680871.0
# 20     Afghanistan       Total  2004  24726684.0
# ...            ...         ...   ...         ...
# 20889     Zimbabwe       Total  2014  13586707.0
# 20894     Zimbabwe       Total  2015  13814629.0
# 20899     Zimbabwe       Total  2016  14030331.0
# 20904     Zimbabwe       Total  2017  14236595.0
# 20909     Zimbabwe       Total  2018  14438802.0
#
# [4430 rows x 4 columns]

# %%
pop2017=pop_total[pop_total['Year']==2017]
pop2017
# Out:
#                          Country Granularity  Year  Population
# 85                   Afghanistan       Total  2017  36296113.0
# 180                      Albania       Total  2017   2884169.0
# 275                      Algeria       Total  2017  41389189.0
# 336               American Samoa       Total  2017     55620.0
# 393                      Andorra       Total  2017     77001.0
# ...                          ...         ...   ...         ...
# 20528  Wallis and Futuna Islands       Total  2017     11900.0
# 20619             Western Sahara       Total  2017    552615.0
# 20714                      Yemen       Total  2017  27834819.0
# 20809                     Zambia       Total  2017  16853599.0
# 20904                   Zimbabwe       Total  2017  14236595.0
#
# [237 rows x 4 columns]

# %%
reg_pop2017 =pd.merge(region_country,pop2017[pop2017['Year']==2017], on= 'Country', how ='right')
reg_pop2017
# Out:
#                     Region                    Country Granularity  Year  \
# 0    Eastern Mediterranean                Afghanistan       Total  2017
# 1                   Europe                    Albania       Total  2017
# 2                   Africa                    Algeria       Total  2017
# 3                      NaN             American Samoa       Total  2017
# 4                   Europe                    Andorra       Total  2017
# ..                     ...                        ...         ...   ...
# 232                    NaN  Wallis and Futuna Islands       Total  2017
# 233                    NaN             Western Sahara       Total  2017
# 234  Eastern Mediterranean                      Yemen       Total  2017
# 235                 Africa                     Zambia       Total  2017
# 236                 Africa                   Zimbabwe       Total  2017
#
#      Population
# 0    36296113.0
# 1     2884169.0
# 2    41389189.0
# 3       55620.0
# ...

# %%
pop2016 = pop_total[pop_total['Year']==2016]
pop2016
# Out:
#                          Country Granularity  Year  Population
# 80                   Afghanistan       Total  2016  35383032.0
# 175                      Albania       Total  2016   2886438.0
# 270                      Algeria       Total  2016  40551392.0
# 333               American Samoa       Total  2016     55741.0
# 390                      Andorra       Total  2016     77297.0
# ...                          ...         ...   ...         ...
# 20525  Wallis and Futuna Islands       Total  2016     12107.0
# 20614             Western Sahara       Total  2016    538749.0
# 20709                      Yemen       Total  2016  27168208.0
# 20804                     Zambia       Total  2016  16363458.0
# 20899                   Zimbabwe       Total  2016  14030331.0
#
# [237 rows x 4 columns]

# %%
pop_total_2018 = pop_total[pop_total['Year']==2018]
pop_total_2018
# Out:
#                          Country Granularity  Year  Population
# 90                   Afghanistan       Total  2018  37171921.0
# 185                      Albania       Total  2018   2882740.0
# 280                      Algeria       Total  2018  42228408.0
# 339               American Samoa       Total  2018     55465.0
# 396                      Andorra       Total  2018     77006.0
# ...                          ...         ...   ...         ...
# 20531  Wallis and Futuna Islands       Total  2018     11661.0
# 20624             Western Sahara       Total  2018    567402.0
# 20719                      Yemen       Total  2018  28498683.0
# 20814                     Zambia       Total  2018  17351708.0
# 20909                   Zimbabwe       Total  2018  14438802.0
#
# [237 rows x 4 columns]

# %%
reg_pop_2018 =pd.merge(region_country,pop_total[pop_total['Year']==2018], on= 'Country', how ='right')
reg_pop_2018
# Out:
#                     Region                    Country Granularity  Year  \
# 0    Eastern Mediterranean                Afghanistan       Total  2018
# 1                   Europe                    Albania       Total  2018
# 2                   Africa                    Algeria       Total  2018
# 3                      NaN             American Samoa       Total  2018
# 4                   Europe                    Andorra       Total  2018
# ..                     ...                        ...         ...   ...
# 232                    NaN  Wallis and Futuna Islands       Total  2018
# 233                    NaN             Western Sahara       Total  2018
# 234  Eastern Mediterranean                      Yemen       Total  2018
# 235                 Africa                     Zambia       Total  2018
# 236                 Africa                   Zimbabwe       Total  2018
#
#      Population
# 0    37171921.0
# 1     2882740.0
# 2    42228408.0
# 3       55465.0
# ...

# %%
#Vérifier les valeurs manquantes
reg_pop_2018[reg_pop_2018['Country'].isna()]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Granularity, Year, Population]
# Index: []

# %%
reg_pop_2018['Country'].duplicated().sum()
# Out:
# 0

# %%
reg_pop_2018.to_csv('population2018.csv')

# %%
#Afficher les 5 dernières lignes du data frame pour vérifier que les données sont bien chargées.
basic_safewaterserv.tail()
# Out:
#        Year   Country Granularity  \
# 10471  2017    Zambia       Total
# 10472  2017    Zambia       Urban
# 10473  2017  Zimbabwe       Rural
# 10474  2017  Zimbabwe       Total
# 10475  2017  Zimbabwe       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 10471                                           59.96376
# 10472                                           83.86312
# 10473                                           49.80476
# 10474                                           64.05123
# 10475                                           93.99767
#
#        Population using safely managed drinking-water services (%)
# 10471                                                NaN
# 10472                                           46.24515
# 10473                                                NaN
# 10474                                                NaN
# 10475                                                NaN

# %%
#Vérifier des valeurs manquantes
basic_safewaterserv.isna().sum()
# Out:
# Year                                                              0
# Country                                                           0
# Granularity                                                       0
# Population using at least basic drinking-water services (%)    1061
# Population using safely managed drinking-water services (%)    7190
# dtype: int64

# %%
#Faire des statisques
basic_safewaterserv.describe(include="all")
# Out:
#                 Year      Country Granularity  \
# count   10476.000000        10476       10476
# unique           NaN          194           3
# top              NaN  Afghanistan       Rural
# freq             NaN           54        3492
# mean     2008.500000          NaN         NaN
# std         5.188375          NaN         NaN
# min      2000.000000          NaN         NaN
# 25%      2004.000000          NaN         NaN
# 50%      2008.500000          NaN         NaN
# 75%      2013.000000          NaN         NaN
# max      2017.000000          NaN         NaN
#
#         Population using at least basic drinking-water services (%)  \
# count                                         9415.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            83.962120
# ...

# %%
#Vérifier les types de données dans les colonnes et compter des valeurs non manquantes
basic_safewaterserv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10476 entries, 0 to 10475
# Data columns (total 5 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         10476 non-null  int64
#  1   Country                                                      10476 non-null  object
#  2   Granularity                                                  10476 non-null  object
#  3   Population using at least basic drinking-water services (%)  9415 non-null   float64
#  4   Population using safely managed drinking-water services (%)  3286 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 409.3+ KB

# %%
basic_safewaterserv["Population using safely managed drinking-water services (%)"]=pd.to_numeric(basic_safewaterserv["Population using safely managed drinking-water services (%)"], errors='coerce')

# %%
basic_safewaterserv["Population using at least basic drinking-water services (%)"]=pd.to_numeric(basic_safewaterserv["Population using at least basic drinking-water services (%)"], errors='coerce')

# %%
#Remplacer des valeurs manquantes NaN, avec 0
basic_safewaterserv.fillna(0,inplace=True)
basic_safewaterserv.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2000      Albania       Rural
# 4  2000      Albania       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           81.78472
# 4                                           87.86662
#
#    Population using safely managed drinking-water services (%)
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                            0.00000
# 4                                           49.29324

# %%
basic_safewaterserv.describe(include="all")
# Out:
#                 Year      Country Granularity  \
# count   10476.000000        10476       10476
# unique           NaN          194           3
# top              NaN  Afghanistan       Rural
# freq             NaN           54        3492
# mean     2008.500000          NaN         NaN
# std         5.188375          NaN         NaN
# min      2000.000000          NaN         NaN
# 25%      2004.000000          NaN         NaN
# 50%      2008.500000          NaN         NaN
# 75%      2013.000000          NaN         NaN
# max      2017.000000          NaN         NaN
#
#         Population using at least basic drinking-water services (%)  \
# count                                        10476.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            75.458511
# ...

# %%
#Vérifier des doublons dans le dataframe basic_safewaterserv
basic_safewaterserv.duplicated().sum()
# Out:
# 0

# %%
#Vérifier des doublons dans la colonne "Country"
basic_safewaterserv["Country"].duplicated().sum()
# Out:
# 10282

# %%
#Vérifier des doublons dans la colonne "Year"
basic_safewaterserv["Year"].duplicated().sum()
# Out:
# 10458

# %%
#Vérifier des valeurs manquantes dans la colonne "Country"
basic_safewaterserv["Country"].isna().sum()
# Out:
# 0

# %%
#Vérifier des valeurs manquantes dans la colonne "Year"
basic_safewaterserv["Year"].isna().sum()
# Out:
# 0

# %%
#Compter des nombres de valeurs différentes dans le dataframe basic_safewaterserv
basic_safewaterserv.nunique()
# Out:
# Year                                                             18
# Country                                                         194
# Granularity                                                       3
# Population using at least basic drinking-water services (%)    7705
# Population using safely managed drinking-water services (%)    2877
# dtype: int64

# %%
basic_safewaterserv
# Out:
#        Year      Country Granularity  \
# 0      2000  Afghanistan       Rural
# 1      2000  Afghanistan       Total
# 2      2000  Afghanistan       Urban
# 3      2000      Albania       Rural
# 4      2000      Albania       Total
# ...     ...          ...         ...
# 10471  2017       Zambia       Total
# 10472  2017       Zambia       Urban
# 10473  2017     Zimbabwe       Rural
# 10474  2017     Zimbabwe       Total
# 10475  2017     Zimbabwe       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 0                                               21.61913
# 1                                               27.77190
# 2                                               49.48745
# 3                                               81.78472
# 4                                               87.86662
# ...                                                  ...
# 10471                                           59.96376
# ...

# %%
total2016_basicsafewater = basic_safewaterserv.loc[(basic_safewaterserv['Granularity']=='Total') & (basic_safewaterserv['Year']==2016)].copy()
total2016_basicsafewater
# Out:
#       Year                             Country Granularity  \
# 9313  2016                         Afghanistan       Total
# 9316  2016                             Albania       Total
# 9319  2016                             Algeria       Total
# 9322  2016                             Andorra       Total
# 9325  2016                              Angola       Total
# ...    ...                                 ...         ...
# 9880  2016  Venezuela (Bolivarian Republic of)       Total
# 9883  2016                            Viet Nam       Total
# 9886  2016                               Yemen       Total
# 9889  2016                              Zambia       Total
# 9892  2016                            Zimbabwe       Total
#
#       Population using at least basic drinking-water services (%)  \
# 9313                                           64.28648
# 9316                                           91.02037
# 9319                                           93.51585
# ...

# %%
total2016_basicsafewater['total2016_moyenne']= (total2016_basicsafewater['Population using at least basic drinking-water services (%)'] + total2016_basicsafewater['Population using safely managed drinking-water services (%)'])/2

# %%
total2016_basicsafewater
# Out:
#       Year                             Country Granularity  \
# 9313  2016                         Afghanistan       Total
# 9316  2016                             Albania       Total
# 9319  2016                             Algeria       Total
# 9322  2016                             Andorra       Total
# 9325  2016                              Angola       Total
# ...    ...                                 ...         ...
# 9880  2016  Venezuela (Bolivarian Republic of)       Total
# 9883  2016                            Viet Nam       Total
# 9886  2016                               Yemen       Total
# 9889  2016                              Zambia       Total
# 9892  2016                            Zimbabwe       Total
#
#       Population using at least basic drinking-water services (%)  \
# 9313                                           64.28648
# 9316                                           91.02037
# 9319                                           93.51585
# ...

# %%
total2016_basicsafewater.drop(['Population using safely managed drinking-water services (%)','total2016_moyenne'],axis=1,inplace=True)

# %%
total2016_basicsafewater
# Out:
#       Year                             Country Granularity  \
# 9313  2016                         Afghanistan       Total
# 9316  2016                             Albania       Total
# 9319  2016                             Algeria       Total
# 9322  2016                             Andorra       Total
# 9325  2016                              Angola       Total
# ...    ...                                 ...         ...
# 9880  2016  Venezuela (Bolivarian Republic of)       Total
# 9883  2016                            Viet Nam       Total
# 9886  2016                               Yemen       Total
# 9889  2016                              Zambia       Total
# 9892  2016                            Zimbabwe       Total
#
#       Population using at least basic drinking-water services (%)
# 9313                                           64.28648
# 9316                                           91.02037
# 9319                                           93.51585
# ...

# %%
chad_basic_safewaterURT_années = basic_safewaterserv[basic_safewaterserv['Country']=='Chad']
chad_basic_safewaterURT_années
# Out:
#       Year Country Granularity  \
# 99    2000    Chad       Rural
# 100   2000    Chad       Total
# 101   2000    Chad       Urban
# 681   2001    Chad       Rural
# 682   2001    Chad       Total
# 683   2001    Chad       Urban
# 1263  2002    Chad       Rural
# 1264  2002    Chad       Total
# 1265  2002    Chad       Urban
# 1845  2003    Chad       Rural
# 1846  2003    Chad       Total
# 1847  2003    Chad       Urban
# 2427  2004    Chad       Rural
# 2428  2004    Chad       Total
# 2429  2004    Chad       Urban
# 3009  2005    Chad       Rural
# 3010  2005    Chad       Total
# 3011  2005    Chad       Urban
# 3591  2006    Chad       Rural
# 3592  2006    Chad       Total
# 3593  2006    Chad       Urban
# 4173  2007    Chad       Rural
# 4174  2007    Chad       Total
# 4175  2007    Chad       Urban
# 4755  2008    Chad       Rural
# 4756  2008    Chad       Total
# 4757  2008    Chad       Urban
# 5337  2009    Chad       Rural
# 5338  2009    Chad       Total
# ...

# %%
options = ['Urban','Rural']
chad_basic_safewaterUR_années = chad_basic_safewaterURT_années[chad_basic_safewaterURT_années["Granularity"].isin(options)]
chad_basic_safewaterUR_années
# Out:
#       Year Country Granularity  \
# 99    2000    Chad       Rural
# 101   2000    Chad       Urban
# 681   2001    Chad       Rural
# 683   2001    Chad       Urban
# 1263  2002    Chad       Rural
# 1265  2002    Chad       Urban
# 1845  2003    Chad       Rural
# 1847  2003    Chad       Urban
# 2427  2004    Chad       Rural
# 2429  2004    Chad       Urban
# 3009  2005    Chad       Rural
# 3011  2005    Chad       Urban
# 3591  2006    Chad       Rural
# 3593  2006    Chad       Urban
# 4173  2007    Chad       Rural
# 4175  2007    Chad       Urban
# 4755  2008    Chad       Rural
# 4757  2008    Chad       Urban
# 5337  2009    Chad       Rural
# 5339  2009    Chad       Urban
# 5919  2010    Chad       Rural
# 5921  2010    Chad       Urban
# 6501  2011    Chad       Rural
# 6503  2011    Chad       Urban
# 7083  2012    Chad       Rural
# 7085  2012    Chad       Urban
# 7665  2013    Chad       Rural
# 7667  2013    Chad       Urban
# 8247  2014    Chad       Rural
# ...

# %%
options = ['Urban']
chad_basic_safewaterU_années = chad_basic_safewaterUR_années[chad_basic_safewaterUR_années["Granularity"].isin(options)]
chad_basic_safewaterU_années
# Out:
#       Year Country Granularity  \
# 101   2000    Chad       Urban
# 683   2001    Chad       Urban
# 1265  2002    Chad       Urban
# 1847  2003    Chad       Urban
# 2429  2004    Chad       Urban
# 3011  2005    Chad       Urban
# 3593  2006    Chad       Urban
# 4175  2007    Chad       Urban
# 4757  2008    Chad       Urban
# 5339  2009    Chad       Urban
# 5921  2010    Chad       Urban
# 6503  2011    Chad       Urban
# 7085  2012    Chad       Urban
# 7667  2013    Chad       Urban
# 8249  2014    Chad       Urban
# 8831  2015    Chad       Urban
# 9413  2016    Chad       Urban
# 9995  2017    Chad       Urban
#
#       Population using at least basic drinking-water services (%)  \
# 101                                            76.47713
# 683                                            76.17123
# 1265                                           75.85481
# 1847                                           75.52791
# 2429                                           75.19051
# ...

# %%
options = ['Rural']
chad_basic_safewaterR_années = chad_basic_safewaterUR_années[chad_basic_safewaterUR_années["Granularity"].isin(options)]
chad_basic_safewaterR_années
# Out:
#       Year Country Granularity  \
# 99    2000    Chad       Rural
# 681   2001    Chad       Rural
# 1263  2002    Chad       Rural
# 1845  2003    Chad       Rural
# 2427  2004    Chad       Rural
# 3009  2005    Chad       Rural
# 3591  2006    Chad       Rural
# 4173  2007    Chad       Rural
# 4755  2008    Chad       Rural
# 5337  2009    Chad       Rural
# 5919  2010    Chad       Rural
# 6501  2011    Chad       Rural
# 7083  2012    Chad       Rural
# 7665  2013    Chad       Rural
# 8247  2014    Chad       Rural
# 8829  2015    Chad       Rural
# 9411  2016    Chad       Rural
# 9993  2017    Chad       Rural
#
#       Population using at least basic drinking-water services (%)  \
# 99                                             31.73133
# 681                                            31.61752
# 1263                                           31.50131
# 1845                                           31.38272
# 2427                                           31.26172
# ...

# %%
chad_basic_safewater = pd.merge(chad_basic_safewaterU_années,chad_basic_safewaterR_années, on=['Country','Year'],how='inner')
chad_basic_safewater
# Out:
#     Year Country Granularity_x  \
# 0   2000    Chad         Urban
# 1   2001    Chad         Urban
# 2   2002    Chad         Urban
# 3   2003    Chad         Urban
# 4   2004    Chad         Urban
# 5   2005    Chad         Urban
# 6   2006    Chad         Urban
# 7   2007    Chad         Urban
# 8   2008    Chad         Urban
# 9   2009    Chad         Urban
# 10  2010    Chad         Urban
# 11  2011    Chad         Urban
# 12  2012    Chad         Urban
# 13  2013    Chad         Urban
# 14  2014    Chad         Urban
# 15  2015    Chad         Urban
# 16  2016    Chad         Urban
# 17  2017    Chad         Urban
#
#     Population using at least basic drinking-water services (%)_x  \
# 0                                            76.47713
# 1                                            76.17123
# 2                                            75.85481
# 3                                            75.52791
# 4                                            75.19051
# ...

# %%
chad_basic_safewater.drop(['Granularity_x','Granularity_y'],axis=1,inplace=True)
chad_basic_safewater
# Out:
#     Year Country  \
# 0   2000    Chad
# 1   2001    Chad
# 2   2002    Chad
# 3   2003    Chad
# 4   2004    Chad
# 5   2005    Chad
# 6   2006    Chad
# 7   2007    Chad
# 8   2008    Chad
# 9   2009    Chad
# 10  2010    Chad
# 11  2011    Chad
# 12  2012    Chad
# 13  2013    Chad
# 14  2014    Chad
# 15  2015    Chad
# 16  2016    Chad
# 17  2017    Chad
#
#     Population using at least basic drinking-water services (%)_x  \
# 0                                            76.47713
# 1                                            76.17123
# 2                                            75.85481
# 3                                            75.52791
# 4                                            75.19051
# 5                                            74.84260
# 6                                            74.48420
# 7                                            74.11530
# 8                                            73.73592
# 9                                            73.34602
# ...

# %%
chad_basic_safewater.rename(columns = {'Population using at least basic drinking-water services (%)_x':'Urban_Population using at least basic drinking-water services (%)','Population using safely managed drinking-water services (%)_x':'Urban_Population using safely managed drinking-water services (%)','Population using at least basic drinking-water services (%)_y':'Rural_Population using at least basic drinking-water services (%)','Population using safely managed drinking-water services (%)_y':'Rural_Population using safely managed drinking-water services (%)'},inplace=True)
chad_basic_safewater
# Out:
#     Year Country  \
# 0   2000    Chad
# 1   2001    Chad
# 2   2002    Chad
# 3   2003    Chad
# 4   2004    Chad
# 5   2005    Chad
# 6   2006    Chad
# 7   2007    Chad
# 8   2008    Chad
# 9   2009    Chad
# 10  2010    Chad
# 11  2011    Chad
# 12  2012    Chad
# 13  2013    Chad
# 14  2014    Chad
# 15  2015    Chad
# 16  2016    Chad
# 17  2017    Chad
#
#     Urban_Population using at least basic drinking-water services (%)  \
# 0                                            76.47713
# 1                                            76.17123
# 2                                            75.85481
# 3                                            75.52791
# 4                                            75.19051
# 5                                            74.84260
# 6                                            74.48420
# 7                                            74.11530
# 8                                            73.73592
# ...

# %%
chad_basic_safewater.to_csv('chad_basic_safewater.csv')

# %%
basic_safewaterserv2017 = basic_safewaterserv[basic_safewaterserv['Year']==2017]
basic_safewaterserv2017
# Out:
#        Year      Country Granularity  \
# 9894   2017  Afghanistan       Rural
# 9895   2017  Afghanistan       Total
# 9896   2017  Afghanistan       Urban
# 9897   2017      Albania       Rural
# 9898   2017      Albania       Total
# ...     ...          ...         ...
# 10471  2017       Zambia       Total
# 10472  2017       Zambia       Urban
# 10473  2017     Zimbabwe       Rural
# 10474  2017     Zimbabwe       Total
# 10475  2017     Zimbabwe       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 9894                                            57.32129
# 9895                                            67.06462
# 9896                                            95.90874
# 9897                                            89.87518
# 9898                                            91.03923
# ...                                                  ...
# 10471                                           59.96376
# ...

# %%
basic_safewater = basic_safewaterserv2017[basic_safewaterserv2017["Granularity"]=="Total"]
basic_safewater
# Out:
#        Year                             Country Granularity  \
# 9895   2017                         Afghanistan       Total
# 9898   2017                             Albania       Total
# 9901   2017                             Algeria       Total
# 9904   2017                             Andorra       Total
# 9907   2017                              Angola       Total
# ...     ...                                 ...         ...
# 10462  2017  Venezuela (Bolivarian Republic of)       Total
# 10465  2017                            Viet Nam       Total
# 10468  2017                               Yemen       Total
# 10471  2017                              Zambia       Total
# 10474  2017                            Zimbabwe       Total
#
#        Population using at least basic drinking-water services (%)  \
# 9895                                            67.06462
# 9898                                            91.03923
# 9901                                            93.55589
# ...

# %%
rural_basic_safewater2017 =basic_safewaterserv2017[basic_safewaterserv2017['Granularity']=='Rural']
rural_basic_safewater2017
# Out:
#        Year                             Country Granularity  \
# 9894   2017                         Afghanistan       Rural
# 9897   2017                             Albania       Rural
# 9900   2017                             Algeria       Rural
# 9903   2017                             Andorra       Rural
# 9906   2017                              Angola       Rural
# ...     ...                                 ...         ...
# 10461  2017  Venezuela (Bolivarian Republic of)       Rural
# 10464  2017                            Viet Nam       Rural
# 10467  2017                               Yemen       Rural
# 10470  2017                              Zambia       Rural
# 10473  2017                            Zimbabwe       Rural
#
#        Population using at least basic drinking-water services (%)  \
# 9894                                            57.32129
# 9897                                            89.87518
# 9900                                            88.69096
# ...

# %%
rural_basic_safewater2017.to_csv('rural_basic_safewater2017.csv')

# %%
urban_basic_safewater2017=basic_safewaterserv2017[basic_safewaterserv2017['Granularity']=='Urban']
urban_basic_safewater2017
# Out:
#        Year                             Country Granularity  \
# 9896   2017                         Afghanistan       Urban
# 9899   2017                             Albania       Urban
# 9902   2017                             Algeria       Urban
# 9905   2017                             Andorra       Urban
# 9908   2017                              Angola       Urban
# ...     ...                                 ...         ...
# 10463  2017  Venezuela (Bolivarian Republic of)       Urban
# 10466  2017                            Viet Nam       Urban
# 10469  2017                               Yemen       Urban
# 10472  2017                              Zambia       Urban
# 10475  2017                            Zimbabwe       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 9896                                            95.90874
# 9899                                            91.83542
# 9902                                            95.44293
# ...

# %%
urban_basic_safewater2017.loc[urban_basic_safewater2017['Country']=='Djibouti']
# Out:
#        Year   Country Granularity  \
# 10043  2017  Djibouti       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 10043                                           83.85837
#
#        Population using safely managed drinking-water services (%)
# 10043                                                0.0

# %%
urban_basic_safewater2017.to_csv('urban_basic_safewater2017.csv')

# %%
option =['Djibouti']
urban_basic_safewater = urban_basic_safewater2017.loc[urban_basic_safewater2017['Country'].isin(option)]
urban_basic_safewater
# Out:
#        Year   Country Granularity  \
# 10043  2017  Djibouti       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 10043                                           83.85837
#
#        Population using safely managed drinking-water services (%)
# 10043                                                0.0

# %%
basic_safewaterserv2016=basic_safewaterserv[basic_safewaterserv['Year']==2016]
basic_safewaterserv2016
# Out:
#       Year      Country Granularity  \
# 9312  2016  Afghanistan       Rural
# 9313  2016  Afghanistan       Total
# 9314  2016  Afghanistan       Urban
# 9315  2016      Albania       Rural
# 9316  2016      Albania       Total
# ...    ...          ...         ...
# 9889  2016       Zambia       Total
# 9890  2016       Zambia       Urban
# 9891  2016     Zimbabwe       Rural
# 9892  2016     Zimbabwe       Total
# 9893  2016     Zimbabwe       Urban
#
#       Population using at least basic drinking-water services (%)  \
# 9312                                           54.84053
# 9313                                           64.28648
# 9314                                           92.59413
# 9315                                           89.87518
# 9316                                           91.02037
# ...                                                 ...
# 9889                                           59.23856
# 9890                                           83.73820
# ...

# %%
basic_safewater2016=basic_safewaterserv[basic_safewaterserv['Granularity']=='Total'].copy()
basic_safewater2016
# Out:
#        Year                             Country Granularity  \
# 1      2000                         Afghanistan       Total
# 4      2000                             Albania       Total
# 7      2000                             Algeria       Total
# 10     2000                             Andorra       Total
# 13     2000                              Angola       Total
# ...     ...                                 ...         ...
# 10462  2017  Venezuela (Bolivarian Republic of)       Total
# 10465  2017                            Viet Nam       Total
# 10468  2017                               Yemen       Total
# 10471  2017                              Zambia       Total
# 10474  2017                            Zimbabwe       Total
#
#        Population using at least basic drinking-water services (%)  \
# 1                                               27.77190
# 4                                               87.86662
# 7                                               89.83726
# ...

# %%
#Remplacer des valeurs manquantes NaN, avec 0
basic_safewater2016.fillna(0,inplace=True)
basic_safewater2016.head()
# Out:
#     Year      Country Granularity  \
# 1   2000  Afghanistan       Total
# 4   2000      Albania       Total
# 7   2000      Algeria       Total
# 10  2000      Andorra       Total
# 13  2000       Angola       Total
#
#     Population using at least basic drinking-water services (%)  \
# 1                                            27.77190
# 4                                            87.86662
# 7                                            89.83726
# 10                                          100.00000
# 13                                           41.14431
#
#     Population using safely managed drinking-water services (%)
# 1                                             0.00000
# 4                                            49.29324
# 7                                             0.00000
# 10                                           90.64000
# 13                                            0.00000

# %%
total_basic_safewater2017=basic_safewaterserv2017[basic_safewaterserv2017['Granularity']=='Total']
total_basic_safewater2017
# Out:
#        Year                             Country Granularity  \
# 9895   2017                         Afghanistan       Total
# 9898   2017                             Albania       Total
# 9901   2017                             Algeria       Total
# 9904   2017                             Andorra       Total
# 9907   2017                              Angola       Total
# ...     ...                                 ...         ...
# 10462  2017  Venezuela (Bolivarian Republic of)       Total
# 10465  2017                            Viet Nam       Total
# 10468  2017                               Yemen       Total
# 10471  2017                              Zambia       Total
# 10474  2017                            Zimbabwe       Total
#
#        Population using at least basic drinking-water services (%)  \
# 9895                                            67.06462
# 9898                                            91.03923
# 9901                                            93.55589
# ...

# %%
total_basic_safewater2017.to_csv('total_basic_safewater2017.csv')

# %%
options=['Rural','Urban']
pop_rural_urban = population[population['Granularity'].isin(options)]
pop_rural_urban
# Out:
#            Country Granularity  Year  Population
# 3      Afghanistan       Rural  2000  15657474.0
# 4      Afghanistan       Urban  2000   4436282.0
# 8      Afghanistan       Rural  2001  16318324.0
# 9      Afghanistan       Urban  2001   4648139.0
# 13     Afghanistan       Rural  2002  17086910.0
# ...            ...         ...   ...         ...
# 20903     Zimbabwe       Urban  2016   5215894.0
# 20907     Zimbabwe       Rural  2017  11201138.0
# 20908     Zimbabwe       Urban  2017   5328766.0
# 20912     Zimbabwe       Rural  2018  11465748.0
# 20913     Zimbabwe       Urban  2018   5447513.0
#
# [8828 rows x 4 columns]

# %%
pop2017_rural= pop_rural_urban[(pop_rural_urban['Granularity']=='Rural') & (pop_rural_urban['Year']==2017)]
pop2017_rural
# Out:
#                          Country Granularity  Year  Population
# 88                   Afghanistan       Rural  2017  26558609.0
# 183                      Albania       Rural  2017   1190155.0
# 278                      Algeria       Rural  2017  11547532.0
# 337               American Samoa       Rural  2017      7139.0
# 394                      Andorra       Rural  2017      9120.0
# ...                          ...         ...   ...         ...
# 20529  Wallis and Futuna Islands       Rural  2017     11773.0
# 20622             Western Sahara       Rural  2017     73931.0
# 20717                      Yemen       Rural  2017  18075808.0
# 20812                     Zambia       Rural  2017   9747709.0
# 20907                   Zimbabwe       Rural  2017  11201138.0
#
# [235 rows x 4 columns]

# %%
pop2017rural=pd.merge(reg_pop2017,pop2017_rural,on ='Country',how ='left')
pop2017rural
# Out:
#                     Region                    Country Granularity_x  Year_x  \
# 0    Eastern Mediterranean                Afghanistan         Total    2017
# 1                   Europe                    Albania         Total    2017
# 2                   Africa                    Algeria         Total    2017
# 3                      NaN             American Samoa         Total    2017
# 4                   Europe                    Andorra         Total    2017
# ..                     ...                        ...           ...     ...
# 232                    NaN  Wallis and Futuna Islands         Total    2017
# 233                    NaN             Western Sahara         Total    2017
# 234  Eastern Mediterranean                      Yemen         Total    2017
# 235                 Africa                     Zambia         Total    2017
# 236                 Africa                   Zimbabwe         Total    2017
#
#      Population_x Granularity_y  Year_y  Population_y
# ...

# %%
pop2017rural.drop(['Granularity_x','Year_x','Year_y','Granularity_y'],axis=1,inplace=True)

# %%
pop2017rural.rename(columns={'Population_x':'Pop_2017_total','Population_y':'Pop_2017_rural'},inplace=True)

# %%
#Insérer une colonne
pop2017rural["taux_pop_rural(%)"]= round((pop2017rural['Pop_2017_rural']/pop2017rural['Pop_2017_total'])*100,2)
pop2017rural
# Out:
#                     Region                    Country  Pop_2017_total  \
# 0    Eastern Mediterranean                Afghanistan      36296113.0
# 1                   Europe                    Albania       2884169.0
# 2                   Africa                    Algeria      41389189.0
# 3                      NaN             American Samoa         55620.0
# 4                   Europe                    Andorra         77001.0
# ..                     ...                        ...             ...
# 232                    NaN  Wallis and Futuna Islands         11900.0
# 233                    NaN             Western Sahara        552615.0
# 234  Eastern Mediterranean                      Yemen      27834819.0
# 235                 Africa                     Zambia      16853599.0
# 236                 Africa                   Zimbabwe      14236595.0
#
#      Pop_2017_rural  taux_pop_rural(%)
# 0        26558609.0              73.17
# 1         1190155.0              41.27
# ...

# %%
options=['Rural','Urban']
basicsafewater_rural_urban = basic_safewaterserv[basic_safewaterserv['Granularity'].isin(options)]
basicsafewater_rural_urban
# Out:
#        Year      Country Granularity  \
# 0      2000  Afghanistan       Rural
# 2      2000  Afghanistan       Urban
# 3      2000      Albania       Rural
# 5      2000      Albania       Urban
# 6      2000      Algeria       Rural
# ...     ...          ...         ...
# 10469  2017        Yemen       Urban
# 10470  2017       Zambia       Rural
# 10472  2017       Zambia       Urban
# 10473  2017     Zimbabwe       Rural
# 10475  2017     Zimbabwe       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 0                                               21.61913
# 2                                               49.48745
# 3                                               81.78472
# 5                                               96.35529
# 6                                               83.32201
# ...                                                  ...
# 10469                                           79.05210
# ...

# %%
basicsafewater2017_rural_urban=basicsafewater_rural_urban[basicsafewater_rural_urban['Year']==2017]
basicsafewater2017_rural_urban
# Out:
#        Year      Country Granularity  \
# 9894   2017  Afghanistan       Rural
# 9896   2017  Afghanistan       Urban
# 9897   2017      Albania       Rural
# 9899   2017      Albania       Urban
# 9900   2017      Algeria       Rural
# ...     ...          ...         ...
# 10469  2017        Yemen       Urban
# 10470  2017       Zambia       Rural
# 10472  2017       Zambia       Urban
# 10473  2017     Zimbabwe       Rural
# 10475  2017     Zimbabwe       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 9894                                            57.32129
# 9896                                            95.90874
# 9897                                            89.87518
# 9899                                            91.83542
# 9900                                            88.69096
# ...                                                  ...
# 10469                                           79.05210
# ...

# %%
options=['Total']
basicsafewater_total = basic_safewaterserv[basic_safewaterserv['Granularity'].isin(options)]
basicsafewater_total
# Out:
#        Year                             Country Granularity  \
# 1      2000                         Afghanistan       Total
# 4      2000                             Albania       Total
# 7      2000                             Algeria       Total
# 10     2000                             Andorra       Total
# 13     2000                              Angola       Total
# ...     ...                                 ...         ...
# 10462  2017  Venezuela (Bolivarian Republic of)       Total
# 10465  2017                            Viet Nam       Total
# 10468  2017                               Yemen       Total
# 10471  2017                              Zambia       Total
# 10474  2017                            Zimbabwe       Total
#
#        Population using at least basic drinking-water services (%)  \
# 1                                               27.77190
# 4                                               87.86662
# 7                                               89.83726
# ...

# %%
#Remplacer des valeurs manquantes NaN, avec 0
basic_safewaterserv.fillna(0,inplace=True)
basic_safewaterserv.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2000      Albania       Rural
# 4  2000      Albania       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           81.78472
# 4                                           87.86662
#
#    Population using safely managed drinking-water services (%)
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                            0.00000
# 4                                           49.29324

# %%
basicsafewater2017_total = basicsafewater_total[basicsafewater_total['Year']==2017]
basicsafewater2017_total
# Out:
#        Year                             Country Granularity  \
# 9895   2017                         Afghanistan       Total
# 9898   2017                             Albania       Total
# 9901   2017                             Algeria       Total
# 9904   2017                             Andorra       Total
# 9907   2017                              Angola       Total
# ...     ...                                 ...         ...
# 10462  2017  Venezuela (Bolivarian Republic of)       Total
# 10465  2017                            Viet Nam       Total
# 10468  2017                               Yemen       Total
# 10471  2017                              Zambia       Total
# 10474  2017                            Zimbabwe       Total
#
#        Population using at least basic drinking-water services (%)  \
# 9895                                            67.06462
# 9898                                            91.03923
# 9901                                            93.55589
# ...

# %%
pop2017_rural_urban = pop_rural_urban[pop_rural_urban['Year']==2017]
pop2017_rural_urban
# Out:
#            Country Granularity  Year  Population
# 88     Afghanistan       Rural  2017  26558609.0
# 89     Afghanistan       Urban  2017   8971472.0
# 183        Albania       Rural  2017   1190155.0
# 184        Albania       Urban  2017   1740032.0
# 278        Algeria       Rural  2017  11547532.0
# ...            ...         ...   ...         ...
# 20718        Yemen       Urban  2017  10174612.0
# 20812       Zambia       Rural  2017   9747709.0
# 20813       Zambia       Urban  2017   7346421.0
# 20907     Zimbabwe       Rural  2017  11201138.0
# 20908     Zimbabwe       Urban  2017   5328766.0
#
# [470 rows x 4 columns]

# %%
basic_safewaterserv[basic_safewaterserv['Year']==2017]
# Out:
#        Year      Country Granularity  \
# 9894   2017  Afghanistan       Rural
# 9895   2017  Afghanistan       Total
# 9896   2017  Afghanistan       Urban
# 9897   2017      Albania       Rural
# 9898   2017      Albania       Total
# ...     ...          ...         ...
# 10471  2017       Zambia       Total
# 10472  2017       Zambia       Urban
# 10473  2017     Zimbabwe       Rural
# 10474  2017     Zimbabwe       Total
# 10475  2017     Zimbabwe       Urban
#
#        Population using at least basic drinking-water services (%)  \
# 9894                                            57.32129
# 9895                                            67.06462
# 9896                                            95.90874
# 9897                                            89.87518
# 9898                                            91.03923
# ...                                                  ...
# 10471                                           59.96376
# ...

# %%
pop2017_basicwater_rural_urban = pd.merge (pop2017_rural_urban,basicsafewater2017_rural_urban,on=['Country','Granularity'], how='right')
pop2017_basicwater_rural_urban
# Out:
#          Country Granularity  Year_x  Population  Year_y  \
# 0    Afghanistan       Rural  2017.0  26558609.0    2017
# 1    Afghanistan       Urban  2017.0   8971472.0    2017
# 2        Albania       Rural  2017.0   1190155.0    2017
# 3        Albania       Urban  2017.0   1740032.0    2017
# 4        Algeria       Rural  2017.0  11547532.0    2017
# ..           ...         ...     ...         ...     ...
# 383        Yemen       Urban  2017.0  10174612.0    2017
# 384       Zambia       Rural  2017.0   9747709.0    2017
# 385       Zambia       Urban  2017.0   7346421.0    2017
# 386     Zimbabwe       Rural  2017.0  11201138.0    2017
# 387     Zimbabwe       Urban  2017.0   5328766.0    2017
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             57.32129
# 1                                             95.90874
# 2                                             89.87518
# ...

# %%
pop2017_basicwater_rural_urban.drop(['Year_x'],axis=1,inplace=True)

# %%
pop2017_basicwater_rural_urban.rename(columns={'Year_y':'Year'},inplace=True)

# %%
pop2017_basicwater_rural_urban
# Out:
#          Country Granularity  Population  Year  \
# 0    Afghanistan       Rural  26558609.0  2017
# 1    Afghanistan       Urban   8971472.0  2017
# 2        Albania       Rural   1190155.0  2017
# 3        Albania       Urban   1740032.0  2017
# 4        Algeria       Rural  11547532.0  2017
# ..           ...         ...         ...   ...
# 383        Yemen       Urban  10174612.0  2017
# 384       Zambia       Rural   9747709.0  2017
# 385       Zambia       Urban   7346421.0  2017
# 386     Zimbabwe       Rural  11201138.0  2017
# 387     Zimbabwe       Urban   5328766.0  2017
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             57.32129
# 1                                             95.90874
# 2                                             89.87518
# 3                                             91.83542
# 4                                             88.69096
# ...

# %%
pop2017_basicwater_rural = pop2017_basicwater_rural_urban[pop2017_basicwater_rural_urban['Granularity']=='Rural'].copy()
pop2017_basicwater_rural
# Out:
#                                 Country Granularity  Population  Year  \
# 0                           Afghanistan       Rural  26558609.0  2017
# 2                               Albania       Rural   1190155.0  2017
# 4                               Algeria       Rural  11547532.0  2017
# 6                               Andorra       Rural      9120.0  2017
# 8                                Angola       Rural  10472554.0  2017
# ..                                  ...         ...         ...   ...
# 378  Venezuela (Bolivarian Republic of)       Rural   3778814.0  2017
# 380                            Viet Nam       Rural  61898302.0  2017
# 382                               Yemen       Rural  18075808.0  2017
# 384                              Zambia       Rural   9747709.0  2017
# 386                            Zimbabwe       Rural  11201138.0  2017
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             57.32129
# ...

# %%
pop2017_basicwater_rural.drop(['Granularity','Year','Population using safely managed drinking-water services (%)'],axis=1,inplace=True)

# %%
pop2017_basicwater_rural
# Out:
#                                 Country  Population  \
# 0                           Afghanistan  26558609.0
# 2                               Albania   1190155.0
# 4                               Algeria  11547532.0
# 6                               Andorra      9120.0
# 8                                Angola  10472554.0
# ..                                  ...         ...
# 378  Venezuela (Bolivarian Republic of)   3778814.0
# 380                            Viet Nam  61898302.0
# 382                               Yemen  18075808.0
# 384                              Zambia   9747709.0
# 386                            Zimbabwe  11201138.0
#
#      Population using at least basic drinking-water services (%)
# 0                                             57.32129
# 2                                             89.87518
# 4                                             88.69096
# 6                                            100.00000
# ...

# %%
pop2017_rural = pd.merge(pop2017_basicwater_rural,pop2017rural,on='Country', how='inner')
pop2017_rural
# Out:
#                                 Country  Population  \
# 0                           Afghanistan  26558609.0
# 1                               Albania   1190155.0
# 2                               Algeria  11547532.0
# 3                               Andorra      9120.0
# 4                                Angola  10472554.0
# ..                                  ...         ...
# 188  Venezuela (Bolivarian Republic of)   3778814.0
# 189                            Viet Nam  61898302.0
# 190                               Yemen  18075808.0
# 191                              Zambia   9747709.0
# 192                            Zimbabwe  11201138.0
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             57.32129
# 1                                             89.87518
# 2                                             88.69096
# 3                                            100.00000
# ...

# %%
pop2017_rural.drop('Population',axis=1,inplace=True)
pop2017_rural
# Out:
#                                 Country  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 188  Venezuela (Bolivarian Republic of)
# 189                            Viet Nam
# 190                               Yemen
# 191                              Zambia
# 192                            Zimbabwe
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             57.32129
# 1                                             89.87518
# 2                                             88.69096
# 3                                            100.00000
# 4                                             27.44429
# ..                                                 ...
# 188                                            0.00000
# ...

# %%
#Identifier la colonne à déplacer
column_to_move = pop2017_rural.pop("Region")
#Insérer une colonne avec insert(location, column_name, column_value)
pop2017_rural.insert(0, "Region", column_to_move )
pop2017_rural
# Out:
#                     Region                             Country  \
# 0    Eastern Mediterranean                         Afghanistan
# 1                   Europe                             Albania
# 2                   Africa                             Algeria
# 3                   Europe                             Andorra
# 4                   Africa                              Angola
# ..                     ...                                 ...
# 188               Americas  Venezuela (Bolivarian Republic of)
# 189        Western Pacific                            Viet Nam
# 190  Eastern Mediterranean                               Yemen
# 191                 Africa                              Zambia
# 192                 Africa                            Zimbabwe
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             57.32129
# 1                                             89.87518
# ...

# %%
pop2017_rural.to_csv('pop2017_rural.csv')

# %%
#Remplacer des valeurs manquantes NaN, avec 0
basic_safewaterserv.fillna(0,inplace=True)
basic_safewaterserv.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2000      Albania       Rural
# 4  2000      Albania       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           81.78472
# 4                                           87.86662
#
#    Population using safely managed drinking-water services (%)
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                            0.00000
# 4                                           49.29324

# %%
pop2017_basicwater_urban = pop2017_basicwater_rural_urban[pop2017_basicwater_rural_urban['Granularity']=='Urban'].copy()
pop2017_basicwater_urban
# Out:
#                                 Country Granularity  Population  Year  \
# 1                           Afghanistan       Urban   8971472.0  2017
# 3                               Albania       Urban   1740032.0  2017
# 5                               Algeria       Urban  29770610.0  2017
# 7                               Andorra       Urban     67845.0  2017
# 9                                Angola       Urban  19311639.0  2017
# ..                                  ...         ...         ...   ...
# 379  Venezuela (Bolivarian Republic of)       Urban  28198251.0  2017
# 381                            Viet Nam       Urban  33642498.0  2017
# 383                               Yemen       Urban  10174612.0  2017
# 385                              Zambia       Urban   7346421.0  2017
# 387                            Zimbabwe       Urban   5328766.0  2017
#
#      Population using at least basic drinking-water services (%)  \
# 1                                             95.90874
# ...

# %%
pop2017_basicwater_urban
# Out:
#                                 Country Granularity  Population  Year  \
# 1                           Afghanistan       Urban   8971472.0  2017
# 3                               Albania       Urban   1740032.0  2017
# 5                               Algeria       Urban  29770610.0  2017
# 7                               Andorra       Urban     67845.0  2017
# 9                                Angola       Urban  19311639.0  2017
# ..                                  ...         ...         ...   ...
# 379  Venezuela (Bolivarian Republic of)       Urban  28198251.0  2017
# 381                            Viet Nam       Urban  33642498.0  2017
# 383                               Yemen       Urban  10174612.0  2017
# 385                              Zambia       Urban   7346421.0  2017
# 387                            Zimbabwe       Urban   5328766.0  2017
#
#      Population using at least basic drinking-water services (%)  \
# 1                                             95.90874
# ...

# %%
#Remplacer des valeurs manquantes NaN, avec 0
basic_safewaterserv.fillna(0,inplace=True)
basic_safewaterserv.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2000      Albania       Rural
# 4  2000      Albania       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           81.78472
# 4                                           87.86662
#
#    Population using safely managed drinking-water services (%)
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                            0.00000
# 4                                           49.29324

# %%
pop2017_basicwater_urban.drop(['Granularity','Year','Population using safely managed drinking-water services (%)'],axis=1,inplace=True)

# %%
pop2017_basicwater_urban
# Out:
#                                 Country  Population  \
# 1                           Afghanistan   8971472.0
# 3                               Albania   1740032.0
# 5                               Algeria  29770610.0
# 7                               Andorra     67845.0
# 9                                Angola  19311639.0
# ..                                  ...         ...
# 379  Venezuela (Bolivarian Republic of)  28198251.0
# 381                            Viet Nam  33642498.0
# 383                               Yemen  10174612.0
# 385                              Zambia   7346421.0
# 387                            Zimbabwe   5328766.0
#
#      Population using at least basic drinking-water services (%)
# 1                                             95.90874
# 3                                             91.83542
# 5                                             95.44293
# 7                                            100.00000
# ...

# %%
pop2017_basicwater_urban.to_csv('pop2017_basicwater_urban.csv')

# %%
pop2017_basicwater_rural_urban.to_csv('pop2017_basicwater_rural_urban.csv')

# %%
#Insérer une colonne
pop2017_urban["taux_pop_urbaine(%)"]= round((pop2017_urban['Pop_2017_urban']/pop2017_urban['Pop_2017_total'])*100,2)
pop2017_urban
# Out:
#                     Region      Country  Pop_2017_total  Pop_2017_urban  \
# 0    Eastern Mediterranean  Afghanistan      26558609.0       8971472.0
# 1    Eastern Mediterranean  Afghanistan       8971472.0       8971472.0
# 2                   Europe      Albania       1190155.0       1740032.0
# 3                   Europe      Albania       1740032.0       1740032.0
# 4                   Africa      Algeria      11547532.0      29770610.0
# ..                     ...          ...             ...             ...
# 465  Eastern Mediterranean        Yemen      10174612.0      10174612.0
# 466                 Africa       Zambia       9747709.0       7346421.0
# 467                 Africa       Zambia       7346421.0       7346421.0
# 468                 Africa     Zimbabwe      11201138.0       5328766.0
# 469                 Africa     Zimbabwe       5328766.0       5328766.0
#
#      taux_pop_urbaine(%)
# 0                  33.78
# 1                 100.00
# ...

# %%
pop2017_urban
# Out:
#                     Region      Country  Pop_2017_total  Pop_2017_urban  \
# 0    Eastern Mediterranean  Afghanistan      26558609.0       8971472.0
# 1    Eastern Mediterranean  Afghanistan       8971472.0       8971472.0
# 2                   Europe      Albania       1190155.0       1740032.0
# 3                   Europe      Albania       1740032.0       1740032.0
# 4                   Africa      Algeria      11547532.0      29770610.0
# ..                     ...          ...             ...             ...
# 465  Eastern Mediterranean        Yemen      10174612.0      10174612.0
# 466                 Africa       Zambia       9747709.0       7346421.0
# 467                 Africa       Zambia       7346421.0       7346421.0
# 468                 Africa     Zimbabwe      11201138.0       5328766.0
# 469                 Africa     Zimbabwe       5328766.0       5328766.0
#
#      taux_pop_urbaine(%)
# 0                  33.78
# 1                 100.00
# ...

# %%
pop2017_urban_basicwater = pd.merge(pop2017_urban,pop2017_basicwater_urban,on='Country',how='inner')
pop2017_urban_basicwater
# Out:
#                     Region      Country  Pop_2017_total  Pop_2017_urban  \
# 0    Eastern Mediterranean  Afghanistan      26558609.0       8971472.0
# 1    Eastern Mediterranean  Afghanistan       8971472.0       8971472.0
# 2                   Europe      Albania       1190155.0       1740032.0
# 3                   Europe      Albania       1740032.0       1740032.0
# 4                   Africa      Algeria      11547532.0      29770610.0
# ..                     ...          ...             ...             ...
# 381  Eastern Mediterranean        Yemen      10174612.0      10174612.0
# 382                 Africa       Zambia       9747709.0       7346421.0
# 383                 Africa       Zambia       7346421.0       7346421.0
# 384                 Africa     Zimbabwe      11201138.0       5328766.0
# 385                 Africa     Zimbabwe       5328766.0       5328766.0
#
#      taux_pop_urbaine(%)  Population  \
# 0                  33.78   8971472.0
# ...

# %%
pop2017_urban_basicwater.drop(['Population'],axis=1,inplace=True)
pop2017_urban_basicwater.head(30)
# Out:
#                    Region              Country  Pop_2017_total  \
# 0   Eastern Mediterranean          Afghanistan      26558609.0
# 1   Eastern Mediterranean          Afghanistan       8971472.0
# 2                  Europe              Albania       1190155.0
# 3                  Europe              Albania       1740032.0
# 4                  Africa              Algeria      11547532.0
# 5                  Africa              Algeria      29770610.0
# 6                  Europe              Andorra          9120.0
# 7                  Europe              Andorra         67845.0
# 8                  Africa               Angola      10472554.0
# 9                  Africa               Angola      19311639.0
# 10               Americas  Antigua and Barbuda         76802.0
# 11               Americas  Antigua and Barbuda         25210.0
# 12               Americas            Argentina       3652804.0
# 13               Americas            Argentina      40618237.0
# ...

# %%
pop2017_urban_basicwater.to_csv('pop2017_urban_basicwater.csv')

# %%
pop2017_rural_basicwater = pd.merge(pop2017_rural,pop2017_basicwater_rural,on='Country',how='inner')
pop2017_rural_basicwater
# Out:
#                     Region                             Country  \
# 0    Eastern Mediterranean                         Afghanistan
# 1                   Europe                             Albania
# 2                   Africa                             Algeria
# 3                   Europe                             Andorra
# 4                   Africa                              Angola
# ..                     ...                                 ...
# 188               Americas  Venezuela (Bolivarian Republic of)
# 189        Western Pacific                            Viet Nam
# 190  Eastern Mediterranean                               Yemen
# 191                 Africa                              Zambia
# 192                 Africa                            Zimbabwe
#
#      Population using at least basic drinking-water services (%)_x  \
# 0                                             57.32129
# 1                                             89.87518
# ...

# %%
#Afficher les 5 premières lignes du data frame pour vérifier que les données sont bien chargées.
political_stability.head()
# Out:
#        Country  Year  Political_Stability Granularity
# 0  Afghanistan  2000                -2.44       Total
# 1  Afghanistan  2002                -2.04       Total
# 2  Afghanistan  2003                -2.20       Total
# 3  Afghanistan  2004                -2.30       Total
# 4  Afghanistan  2005                -2.07       Total

# %%
#Afficher les 5 dernières lignes du data frame pour vérifier que les données sont bien chargées.
political_stability.tail()
# Out:
#        Country  Year  Political_Stability Granularity
# 3521  Zimbabwe  2014                -0.71       Total
# 3522  Zimbabwe  2015                -0.62       Total
# 3523  Zimbabwe  2016                -0.62       Total
# 3524  Zimbabwe  2017                -0.71       Total
# 3525  Zimbabwe  2018                -0.71       Total

# %%
#vérifier l'ensemble de données importées
political_stability.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3526 entries, 0 to 3525
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              3526 non-null   object
#  1   Year                 3526 non-null   int64
#  2   Political_Stability  3526 non-null   float64
#  3   Granularity          3526 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 110.3+ KB

# %%
#Faire des statistiques 
political_stability.describe(include="all")
# Out:
#             Country         Year  Political_Stability Granularity
# count          3526  3526.000000          3526.000000        3526
# unique          200          NaN                  NaN           1
# top     Afghanistan          NaN                  NaN       Total
# freq             18          NaN                  NaN        3526
# mean            NaN  2009.521838            -0.051044         NaN
# std             NaN     5.255833             0.996039         NaN
# min             NaN  2000.000000            -3.310000         NaN
# 25%             NaN  2005.000000            -0.710000         NaN
# 50%             NaN  2010.000000             0.050000         NaN
# 75%             NaN  2014.000000             0.797500         NaN
# max             NaN  2018.000000             1.970000         NaN

# %%
#Vérifier des valeurs manquantes
political_stability.isna().sum()
# Out:
# Country                0
# Year                   0
# Political_Stability    0
# Granularity            0
# dtype: int64

# %%
#Déterminer les types de données
political_stability.dtypes
# Out:
# Country                 object
# Year                     int64
# Political_Stability    float64
# Granularity             object
# dtype: object

# %%
political_stability['Year'].astype (object)
# Out:
# 0       2000
# 1       2002
# 2       2003
# 3       2004
# 4       2005
#         ...
# 3521    2014
# 3522    2015
# 3523    2016
# 3524    2017
# 3525    2018
# Name: Year, Length: 3526, dtype: object

# %%
#Vérifier des doublons dans le dataframe
political_stability.duplicated().sum()
# Out:
# 0

# %%
#Vérifier des valeurs manquantes dans la colonne "Country"
political_stability["Country"].isna().sum()
# Out:
# 0

# %%
#Vérifier des doublons dans la colonne "Country"
political_stability["Country"].duplicated().sum()
# Out:
# 3326

# %%
#lister des nombres de valeurs différentes au sein de dataframe 
political_stability.nunique()
# Out:
# Country                200
# Year                    18
# Political_Stability    444
# Granularity              1
# dtype: int64

# %%
#Remplacer des valeurs manquantes NaN, avec 0
political_stability.fillna(0,inplace=True)
political_stability.head()
# Out:
#        Country  Year  Political_Stability Granularity
# 0  Afghanistan  2000                -2.44       Total
# 1  Afghanistan  2002                -2.04       Total
# 2  Afghanistan  2003                -2.20       Total
# 3  Afghanistan  2004                -2.30       Total
# 4  Afghanistan  2005                -2.07       Total

# %%
pol_stab2016 = political_stability[political_stability['Year']==2016]
pol_stab2016
# Out:
#                                  Country  Year  Political_Stability  \
# 15                           Afghanistan  2016                -2.67
# 33                               Albania  2016                 0.34
# 51                               Algeria  2016                -1.10
# 66                        American Samoa  2016                 1.19
# 84                               Andorra  2016                 1.41
# ...                                  ...   ...                  ...
# 3451  Venezuela (Bolivarian Republic of)  2016                -1.02
# 3469                            Viet Nam  2016                 0.23
# 3487                               Yemen  2016                -2.79
# 3505                              Zambia  2016                 0.14
# 3523                            Zimbabwe  2016                -0.62
#
#      Granularity
# 15         Total
# 33         Total
# 51         Total
# 66         Total
# 84         Total
# ...          ...
# 3451       Total
# ...

# %%
chad_polstab = political_stability[political_stability['Country']=='Chad']
chad_polstab
# Out:
#     Country  Year  Political_Stability Granularity
# 627    Chad  2000                -1.14       Total
# 628    Chad  2002                -1.56       Total
# 629    Chad  2003                -1.37       Total
# 630    Chad  2004                -1.54       Total
# 631    Chad  2005                -1.44       Total
# 632    Chad  2006                -1.83       Total
# 633    Chad  2007                -1.87       Total
# 634    Chad  2008                -1.97       Total
# 635    Chad  2009                -1.73       Total
# 636    Chad  2010                -1.52       Total
# 637    Chad  2011                -1.32       Total
# 638    Chad  2012                -1.04       Total
# 639    Chad  2013                -1.09       Total
# 640    Chad  2014                -1.57       Total
# 641    Chad  2015                -0.97       Total
# 642    Chad  2016                -1.30       Total
# 643    Chad  2017                -1.29       Total
# ...

# %%
chad_polstab.to_csv('chad_polstab.csv')

# %%
pol_stab2018 = political_stability[political_stability['Year']==2018]
pol_stab2018
# Out:
#                                  Country  Year  Political_Stability  \
# 17                           Afghanistan  2018                -2.75
# 35                               Albania  2018                 0.38
# 53                               Algeria  2018                -0.79
# 68                        American Samoa  2018                 1.21
# 86                               Andorra  2018                 1.43
# ...                                  ...   ...                  ...
# 3453  Venezuela (Bolivarian Republic of)  2018                -1.34
# 3471                            Viet Nam  2018                 0.20
# 3489                               Yemen  2018                -3.00
# 3507                              Zambia  2018                 0.14
# 3525                            Zimbabwe  2018                -0.71
#
#      Granularity
# 17         Total
# 35         Total
# 53         Total
# 68         Total
# 86         Total
# ...          ...
# 3453       Total
# ...

# %%
pol_stab2018.to_csv('pol_stab2018.csv')

# %%
pol_stab = political_stability.pivot_table(index='Country',columns='Year', values='Political_Stability')
pol_stab.reset_index()
# Out:
# Year                             Country  2000  2002  2003  2004  2005  2006  \
# 0                            Afghanistan -2.44 -2.04 -2.20 -2.30 -2.07 -2.22
# 1                                Albania -0.54 -0.29 -0.31 -0.43 -0.51 -0.51
# 2                                Algeria -1.43 -1.63 -1.75 -1.36 -0.92 -1.13
# 3                         American Samoa   NaN   NaN   NaN  0.74  0.75  0.70
# 4                                Andorra  1.17  1.28  1.46  1.40  1.38  1.35
# ..                                   ...   ...   ...   ...   ...   ...   ...
# 195   Venezuela (Bolivarian Republic of) -0.76 -1.32 -1.29 -1.39 -1.25 -1.25
# 196                             Viet Nam  0.41  0.35  0.13  0.15  0.48  0.40
# 197                                Yemen -1.14 -1.31 -1.48 -1.55 -1.44 -1.35
# 198                               Zambia  0.03 -0.28  0.22  0.19  0.11  0.36
# 199                             Zimbabwe -1.32 -1.52 -1.09 -1.21 -1.27 -0.93
#
# ...

# %%
pol_stab.to_csv("pol_stab.csv")

# %%
pop2016_pol_stab = pd.merge(reg_pop_2018,political_stability[political_stability['Year']==2016], on= 'Country', how = 'right')
pop2016_pol_stab
# Out:
#                     Region                             Country Granularity_x  \
# 0    Eastern Mediterranean                         Afghanistan         Total
# 1                   Europe                             Albania         Total
# 2                   Africa                             Algeria         Total
# 3                      NaN                      American Samoa         Total
# 4                   Europe                             Andorra         Total
# ..                     ...                                 ...           ...
# 193               Americas  Venezuela (Bolivarian Republic of)         Total
# 194        Western Pacific                            Viet Nam         Total
# 195  Eastern Mediterranean                               Yemen         Total
# 196                 Africa                              Zambia         Total
# 197                 Africa                            Zimbabwe         Total
#
# ...

# %%
pop2016_pol_stab.drop(['Granularity_x','Year_x','Granularity_y'],axis=1,inplace=True)

# %%
pop2016_pol_stab.rename(columns = {'Year_y':'Year'},inplace=True)

# %%
pop2016_pol_stab
# Out:
#                     Region                             Country  Population  \
# 0    Eastern Mediterranean                         Afghanistan  37171921.0
# 1                   Europe                             Albania   2882740.0
# 2                   Africa                             Algeria  42228408.0
# 3                      NaN                      American Samoa     55465.0
# 4                   Europe                             Andorra     77006.0
# ..                     ...                                 ...         ...
# 193               Americas  Venezuela (Bolivarian Republic of)  28887118.0
# 194        Western Pacific                            Viet Nam  95545962.0
# 195  Eastern Mediterranean                               Yemen  28498683.0
# 196                 Africa                              Zambia  17351708.0
# 197                 Africa                            Zimbabwe  14438802.0
#
#      Year  Political_Stability
# 0    2016                -2.67
# ...

# %%
pop2016_pol_stab.to_csv('pop2016_pol_stab.csv')

# %%
options=['Chad','Afghanistan','Democratic Republic of the Congo','Syrian Arab Republic']
pop2016_polstab = pop2016_pol_stab.loc[pop2016_pol_stab['Country'].isin(options)]
pop2016_polstab
# Out:
#                     Region                           Country  Population  \
# 0    Eastern Mediterranean                       Afghanistan  37171921.0
# 35                  Africa                              Chad  15477729.0
# 51                  Africa  Democratic Republic of the Congo  84068091.0
# 173  Eastern Mediterranean              Syrian Arab Republic  16945057.0
#
#      Year  Political_Stability
# 0    2016                -2.67
# 35   2016                -1.30
# 51   2016                -2.23
# 173  2016                -2.92

# %%
pol_stab2018= political_stability.loc[political_stability['Year']==2018]
pol_stab2018
# Out:
#                                  Country  Year  Political_Stability  \
# 17                           Afghanistan  2018                -2.75
# 35                               Albania  2018                 0.38
# 53                               Algeria  2018                -0.79
# 68                        American Samoa  2018                 1.21
# 86                               Andorra  2018                 1.43
# ...                                  ...   ...                  ...
# 3453  Venezuela (Bolivarian Republic of)  2018                -1.34
# 3471                            Viet Nam  2018                 0.20
# 3489                               Yemen  2018                -3.00
# 3507                              Zambia  2018                 0.14
# 3525                            Zimbabwe  2018                -0.71
#
#      Granularity
# 17         Total
# 35         Total
# 53         Total
# 68         Total
# 86         Total
# ...          ...
# 3453       Total
# ...

# %%
pop2018_pol_stab = pd.merge(reg_pop_2018,political_stability[political_stability['Year']==2018], on= 'Country', how = 'right')
pop2018_pol_stab
# Out:
#                     Region                             Country Granularity_x  \
# 0    Eastern Mediterranean                         Afghanistan         Total
# 1                   Europe                             Albania         Total
# 2                   Africa                             Algeria         Total
# 3                      NaN                      American Samoa         Total
# 4                   Europe                             Andorra         Total
# ..                     ...                                 ...           ...
# 193               Americas  Venezuela (Bolivarian Republic of)         Total
# 194        Western Pacific                            Viet Nam         Total
# 195  Eastern Mediterranean                               Yemen         Total
# 196                 Africa                              Zambia         Total
# 197                 Africa                            Zimbabwe         Total
#
# ...

# %%
pop2018_pol_stab.drop(['Granularity_x','Year_x'],axis=1,inplace=True)

# %%
pop2018_pol_stab.rename(columns = {'Year_y':'Year','Granularity_y':'Granularity'},inplace=True)

# %%
pop2018_pol_stab
# Out:
#                     Region                             Country  Population  \
# 0    Eastern Mediterranean                         Afghanistan  37171921.0
# 1                   Europe                             Albania   2882740.0
# 2                   Africa                             Algeria  42228408.0
# 3                      NaN                      American Samoa     55465.0
# 4                   Europe                             Andorra     77006.0
# ..                     ...                                 ...         ...
# 193               Americas  Venezuela (Bolivarian Republic of)  28887118.0
# 194        Western Pacific                            Viet Nam  95545962.0
# 195  Eastern Mediterranean                               Yemen  28498683.0
# 196                 Africa                              Zambia  17351708.0
# 197                 Africa                            Zimbabwe  14438802.0
#
#      Year  Political_Stability Granularity
# ...

# %%
#Identifier le column à déplacer
column_to_move = pop2018_pol_stab.pop("Granularity")
#Insérer column with insert(location, column_name, column_value)
pop2018_pol_stab.insert(2, "Granularity", column_to_move )

# %%
pop2018_pol_stab
# Out:
#                     Region                             Country Granularity  \
# 0    Eastern Mediterranean                         Afghanistan       Total
# 1                   Europe                             Albania       Total
# 2                   Africa                             Algeria       Total
# 3                      NaN                      American Samoa       Total
# 4                   Europe                             Andorra       Total
# ..                     ...                                 ...         ...
# 193               Americas  Venezuela (Bolivarian Republic of)       Total
# 194        Western Pacific                            Viet Nam       Total
# 195  Eastern Mediterranean                               Yemen       Total
# 196                 Africa                              Zambia       Total
# 197                 Africa                            Zimbabwe       Total
#
#      Population  Year  Political_Stability
# ...

# %%
pop2018_pol_stab
# Out:
#                     Region                             Country Granularity  \
# 0    Eastern Mediterranean                         Afghanistan       Total
# 1                   Europe                             Albania       Total
# 2                   Africa                             Algeria       Total
# 3                      NaN                      American Samoa       Total
# 4                   Europe                             Andorra       Total
# ..                     ...                                 ...         ...
# 193               Americas  Venezuela (Bolivarian Republic of)       Total
# 194        Western Pacific                            Viet Nam       Total
# 195  Eastern Mediterranean                               Yemen       Total
# 196                 Africa                              Zambia       Total
# 197                 Africa                            Zimbabwe       Total
#
#      Population  Year  Political_Stability
# ...

# %%
pop2018_pol_stab.to_csv('pop2018_pol_stab.csv')

# %%
mortality_rate.head()
# Out:
#    Year      Country Granularity  \
# 0  2016  Afghanistan      Female
# 1  2016  Afghanistan        Male
# 2  2016  Afghanistan       Total
# 3  2016      Albania      Female
# 4  2016      Albania        Male
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths
# 0                                           15.31193                      NaN
# 1                                           12.61297                      NaN
# 2                                           13.92067                 4824.353
# 3                                            0.12552                      NaN
# 4                                            0.20650                      NaN

# %%
mortality_rate.tail()
# Out:
#      Year   Country Granularity  \
# 544  2016    Zambia        Male
# 545  2016    Zambia       Total
# 546  2016  Zimbabwe      Female
# 547  2016  Zimbabwe        Male
# 548  2016  Zimbabwe       Total
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 544                                           36.61913
# 545                                           34.91273
# 546                                           22.16388
# 547                                           27.06688
# 548                                           24.55074
#
#      WASH deaths
# 544          NaN
# 545     5792.504
# 546          NaN
# 547          NaN
# 548     3965.033

# %%
#Faire des statistiques 
mortality_rate.describe(include="all")
# Out:
#           Year      Country Granularity  \
# count    549.0          549         549
# unique     NaN          183           3
# top        NaN  Afghanistan      Female
# freq       NaN            3         183
# mean    2016.0          NaN         NaN
# std        0.0          NaN         NaN
# min     2016.0          NaN         NaN
# 25%     2016.0          NaN         NaN
# 50%     2016.0          NaN         NaN
# 75%     2016.0          NaN         NaN
# max     2016.0          NaN         NaN
#
#         Mortality rate attributed to exposure to unsafe WASH services  \
# count                                          549.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            12.493876
# std                                             20.830508
# ...

# %%
#vérifier l'ensemble de données importées
mortality_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 5 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Year                                                           549 non-null    int64
#  1   Country                                                        549 non-null    object
#  2   Granularity                                                    549 non-null    object
#  3   Mortality rate attributed to exposure to unsafe WASH services  549 non-null    float64
#  4   WASH deaths                                                    183 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 21.6+ KB

# %%
mort_rate = mortality_rate.set_index(['Country','Granularity'])
mort_rate
# Out:
#                          Year  \
# Country     Granularity
# Afghanistan Female       2016
#             Male         2016
#             Total        2016
# Albania     Female       2016
#             Male         2016
# ...                       ...
# Zambia      Male         2016
#             Total        2016
# Zimbabwe    Female       2016
#             Male         2016
#             Total        2016
#
#                          Mortality rate attributed to exposure to unsafe WASH services  \
# Country     Granularity
# Afghanistan Female                                                15.31193
#             Male                                                  12.61297
#             Total                                                 13.92067
# Albania     Female                                                 0.12552
#             Male                                                   0.20650
# ...                                                                    ...
# ...

# %%
mort_rate.index
# Out:
# MultiIndex([('Afghanistan', 'Female'),
#             ('Afghanistan',   'Male'),
#             ('Afghanistan',  'Total'),
#             (    'Albania', 'Female'),
#             (    'Albania',   'Male'),
#             (    'Albania',  'Total'),
#             (    'Algeria', 'Female'),
#             (    'Algeria',   'Male'),
#             (    'Algeria',  'Total'),
#             (     'Angola', 'Female'),
#             ...
#             (   'Viet Nam',  'Total'),
#             (      'Yemen', 'Female'),
#             (      'Yemen',   'Male'),
#             (      'Yemen',  'Total'),
#             (     'Zambia', 'Female'),
#             (     'Zambia',   'Male'),
#             (     'Zambia',  'Total'),
#             (   'Zimbabwe', 'Female'),
#             (   'Zimbabwe',   'Male'),
#             (   'Zimbabwe',  'Total')],
#            names=['Country', 'Granularity'], length=549)

# %%
#Vérifier des valeurs manquantes
mortality_rate.isna().sum()
# Out:
# Year                                                               0
# Country                                                            0
# Granularity                                                        0
# Mortality rate attributed to exposure to unsafe WASH services      0
# WASH deaths                                                      366
# dtype: int64

# %%
#Vérifier des doublons dans le dataframe basic_safewaterserv
mortality_rate.duplicated().sum()
# Out:
# 0

# %%
#Vérifier des doublons dans la colonne "Country"
mortality_rate["Country"].duplicated().sum()
# Out:
# 366

# %%
#lister des nombres de valeurs différentes au sein de dataframe 
mortality_rate.nunique()
# Out:
# Year                                                               1
# Country                                                          183
# Granularity                                                        3
# Mortality rate attributed to exposure to unsafe WASH services    548
# WASH deaths                                                      183
# dtype: int64

# %%
mortality_rate["WASH deaths"]=pd.to_numeric(mortality_rate["WASH deaths"], errors='coerce')

# %%
#Remplacer des valeurs manquantes NaN, avec 0
mortality_rate.fillna(0,inplace=True)
mortality_rate.head()
# Out:
#    Year      Country Granularity  \
# 0  2016  Afghanistan      Female
# 1  2016  Afghanistan        Male
# 2  2016  Afghanistan       Total
# 3  2016      Albania      Female
# 4  2016      Albania        Male
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths
# 0                                           15.31193                    0.000
# 1                                           12.61297                    0.000
# 2                                           13.92067                 4824.353
# 3                                            0.12552                    0.000
# 4                                            0.20650                    0.000

# %%
mortality_rate_total = mortality_rate.loc[mortality_rate['Granularity']=='Total']
mortality_rate_total
# Out:
#      Year                             Country Granularity  \
# 2    2016                         Afghanistan       Total
# 5    2016                             Albania       Total
# 8    2016                             Algeria       Total
# 11   2016                              Angola       Total
# 14   2016                 Antigua and Barbuda       Total
# ..    ...                                 ...         ...
# 536  2016  Venezuela (Bolivarian Republic of)       Total
# 539  2016                            Viet Nam       Total
# 542  2016                               Yemen       Total
# 545  2016                              Zambia       Total
# 548  2016                            Zimbabwe       Total
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 2                                             13.92067
# 5                                              0.16641
# 8                                              1.86723
# ...

# %%
pop2016_total = df_poptotal[df_poptotal['Year']==2016]
pop2016_total
# Out:
#                          Country Granularity  Year  Population
# 80                   Afghanistan       Total  2016  35383032.0
# 175                      Albania       Total  2016   2886438.0
# 270                      Algeria       Total  2016  40551392.0
# 333               American Samoa       Total  2016     55741.0
# 390                      Andorra       Total  2016     77297.0
# ...                          ...         ...   ...         ...
# 20525  Wallis and Futuna Islands       Total  2016     12107.0
# 20614             Western Sahara       Total  2016    538749.0
# 20709                      Yemen       Total  2016  27168208.0
# 20804                     Zambia       Total  2016  16363458.0
# 20899                   Zimbabwe       Total  2016  14030331.0
#
# [237 rows x 4 columns]

# %%
pop2016_mortality_rate = pd.merge(pop2016_total,mortality_rate_total, on =['Country','Granularity','Year'], how = 'inner')
pop2016_mortality_rate
# Out:
#                                 Country Granularity  Year  Population  \
# 0                           Afghanistan       Total  2016  35383032.0
# 1                               Albania       Total  2016   2886438.0
# 2                               Algeria       Total  2016  40551392.0
# 3                                Angola       Total  2016  28842489.0
# 4                   Antigua and Barbuda       Total  2016     94527.0
# ..                                  ...         ...   ...         ...
# 177  Venezuela (Bolivarian Republic of)       Total  2016  29851255.0
# 178                            Viet Nam       Total  2016  93640422.0
# 179                               Yemen       Total  2016  27168208.0
# 180                              Zambia       Total  2016  16363458.0
# 181                            Zimbabwe       Total  2016  14030331.0
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 0                                             13.92067
# ...

# %%
#Identifier le column à déplacer
column_to_move = pop2016_mortality_rate.pop("Year")
#Insérer column with insert(location, column_name, column_value)
pop2016_mortality_rate.insert(0, "Year", column_to_move )

# %%
pop2016_mortality_rate
# Out:
#      Year                             Country Granularity  Population  \
# 0    2016                         Afghanistan       Total  35383032.0
# 1    2016                             Albania       Total   2886438.0
# 2    2016                             Algeria       Total  40551392.0
# 3    2016                              Angola       Total  28842489.0
# 4    2016                 Antigua and Barbuda       Total     94527.0
# ..    ...                                 ...         ...         ...
# 177  2016  Venezuela (Bolivarian Republic of)       Total  29851255.0
# 178  2016                            Viet Nam       Total  93640422.0
# 179  2016                               Yemen       Total  27168208.0
# 180  2016                              Zambia       Total  16363458.0
# 181  2016                            Zimbabwe       Total  14030331.0
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 0                                             13.92067
# ...

# %%
pop2016_mortality_rate.to_csv('pop2016_mortality_rate.csv')

# %%
options=['Chad','Afghanistan','Democratic Republic of the Congo','Syrian Arab Republic']
pop2016_polstab_mortality = pop2016_mortality_rate.loc[pop2016_mortality_rate['Country'].isin(options)]
pop2016_polstab_mortality
# Out:
#      Year                           Country Granularity  Population  \
# 0    2016                       Afghanistan       Total  35383032.0
# 32   2016                              Chad       Total  14561660.0
# 45   2016  Democratic Republic of the Congo       Total  78789127.0
# 158  2016              Syrian Arab Republic       Total  17465575.0
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 0                                             13.92067
# 32                                           101.04312
# 45                                            59.75592
# 158                                            3.66540
#
#      WASH deaths
# 0      4824.3530
# 32    14603.3000
# 45    47049.5200
# 158     675.5495

# %%
pop2016_pol_mort=pd.merge(pop2016_polstab,pop2016_polstab_mortality,on=['Country','Year'],how='inner')
pop2016_pol_mort
# Out:
#                   Region                           Country  Population_x  \
# 0  Eastern Mediterranean                       Afghanistan    37171921.0
# 1                 Africa                              Chad    15477729.0
# 2                 Africa  Democratic Republic of the Congo    84068091.0
# 3  Eastern Mediterranean              Syrian Arab Republic    16945057.0
#
#    Year  Political_Stability Granularity  Population_y  \
# 0  2016                -2.67       Total    35383032.0
# 1  2016                -1.30       Total    14561660.0
# 2  2016                -2.23       Total    78789127.0
# 3  2016                -2.92       Total    17465575.0
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths
# 0                                           13.92067                4824.3530
# 1                                          101.04312               14603.3000
# 2                                           59.75592               47049.5200
# ...

# %%
pop2016_pol_mort.rename(columns={'Population_x':'Population_m/f','Population_y':'Population_u/r'},inplace=True)
pop2016_pol_mort
# Out:
#                   Region                           Country  Population_m/f  \
# 0  Eastern Mediterranean                       Afghanistan      37171921.0
# 1                 Africa                              Chad      15477729.0
# 2                 Africa  Democratic Republic of the Congo      84068091.0
# 3  Eastern Mediterranean              Syrian Arab Republic      16945057.0
#
#    Year  Political_Stability Granularity  Population_u/r  \
# 0  2016                -2.67       Total      35383032.0
# 1  2016                -1.30       Total      14561660.0
# 2  2016                -2.23       Total      78789127.0
# 3  2016                -2.92       Total      17465575.0
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths
# 0                                           13.92067                4824.3530
# 1                                          101.04312               14603.3000
# ...

# %%
polstab2016_basicsafewater=pd.merge(pop2016_pol_mort,basic_safewater2016,on=['Country','Year'],how='inner')
polstab2016_basicsafewater
# Out:
#                   Region                           Country  Population_m/f  \
# 0  Eastern Mediterranean                       Afghanistan      37171921.0
# 1                 Africa                              Chad      15477729.0
# 2                 Africa  Democratic Republic of the Congo      84068091.0
# 3  Eastern Mediterranean              Syrian Arab Republic      16945057.0
#
#    Year  Political_Stability Granularity_x  Population_u/r  \
# 0  2016                -2.67         Total      35383032.0
# 1  2016                -1.30         Total      14561660.0
# 2  2016                -2.23         Total      78789127.0
# 3  2016                -2.92         Total      17465575.0
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths  \
# 0                                           13.92067                4824.3530
# 1                                          101.04312               14603.3000
# ...

# %%
polstab2016_basicsafewater.drop(['Population_m/f','Year','Granularity_x','Population_u/r','Granularity_x','Granularity_y','WASH deaths'],axis=1,inplace=True)
polstab2016_basicsafewater
# Out:
#                   Region                           Country  \
# 0  Eastern Mediterranean                       Afghanistan
# 1                 Africa                              Chad
# 2                 Africa  Democratic Republic of the Congo
# 3  Eastern Mediterranean              Syrian Arab Republic
#
#    Political_Stability  \
# 0                -2.67
# 1                -1.30
# 2                -2.23
# 3                -2.92
#
#    Mortality rate attributed to exposure to unsafe WASH services  \
# 0                                           13.92067
# 1                                          101.04312
# 2                                           59.75592
# 3                                            3.66540
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           64.28648
# 1                                           38.85259
# 2                                           42.97677
# ...

# %%
polstab2016_basicsafewater.to_csv('polstab2016_basicsafewater.csv')

# %%
pop2016_mortality_rate.drop(['WASH deaths'],axis=1,inplace=True)

# %%
pop2016_mortality_rate
# Out:
#      Year                             Country Granularity  Population  \
# 0    2016                         Afghanistan       Total  35383032.0
# 1    2016                             Albania       Total   2886438.0
# 2    2016                             Algeria       Total  40551392.0
# 3    2016                              Angola       Total  28842489.0
# 4    2016                 Antigua and Barbuda       Total     94527.0
# ..    ...                                 ...         ...         ...
# 177  2016  Venezuela (Bolivarian Republic of)       Total  29851255.0
# 178  2016                            Viet Nam       Total  93640422.0
# 179  2016                               Yemen       Total  27168208.0
# 180  2016                              Zambia       Total  16363458.0
# 181  2016                            Zimbabwe       Total  14030331.0
#
#      Mortality rate attributed to exposure to unsafe WASH services
# 0                                             13.92067
# ...

# %%
pop2016_mortality_rate['Population suvie (%)']= 100-pop2016_mortality_rate['Mortality rate attributed to exposure to unsafe WASH services']

# %%
pop2016_mortality_rate
# Out:
#      Year                             Country Granularity  Population  \
# 0    2016                         Afghanistan       Total  35383032.0
# 1    2016                             Albania       Total   2886438.0
# 2    2016                             Algeria       Total  40551392.0
# 3    2016                              Angola       Total  28842489.0
# 4    2016                 Antigua and Barbuda       Total     94527.0
# ..    ...                                 ...         ...         ...
# 177  2016  Venezuela (Bolivarian Republic of)       Total  29851255.0
# 178  2016                            Viet Nam       Total  93640422.0
# 179  2016                               Yemen       Total  27168208.0
# 180  2016                              Zambia       Total  16363458.0
# 181  2016                            Zimbabwe       Total  14030331.0
#
#      Mortality rate attributed to exposure to unsafe WASH services  \
# 0                                             13.92067
# ...

# %%
pop2016_popsurvie = pd.merge(total2016_basicsafewater,pop2016_mortality_rate, on=['Country','Year','Granularity'],how='inner')
pop2016_popsurvie
# Out:
#      Year                             Country Granularity  \
# 0    2016                         Afghanistan       Total
# 1    2016                             Albania       Total
# 2    2016                             Algeria       Total
# 3    2016                              Angola       Total
# 4    2016                 Antigua and Barbuda       Total
# ..    ...                                 ...         ...
# 177  2016  Venezuela (Bolivarian Republic of)       Total
# 178  2016                            Viet Nam       Total
# 179  2016                               Yemen       Total
# 180  2016                              Zambia       Total
# 181  2016                            Zimbabwe       Total
#
#      Population using at least basic drinking-water services (%)  Population  \
# 0                                             64.28648            35383032.0
# 1                                             91.02037             2886438.0
# ...

# %%
#Identifier le column à déplacer
column_to_move = pop2016_popsurvie.pop("Population")
#Insérer column with insert(location, column_name, column_value)
pop2016_popsurvie.insert(3, "Population", column_to_move )

# %%
pop2016_popsurvie
# Out:
#      Year                             Country Granularity  Population  \
# 0    2016                         Afghanistan       Total  35383032.0
# 1    2016                             Albania       Total   2886438.0
# 2    2016                             Algeria       Total  40551392.0
# 3    2016                              Angola       Total  28842489.0
# 4    2016                 Antigua and Barbuda       Total     94527.0
# ..    ...                                 ...         ...         ...
# 177  2016  Venezuela (Bolivarian Republic of)       Total  29851255.0
# 178  2016                            Viet Nam       Total  93640422.0
# 179  2016                               Yemen       Total  27168208.0
# 180  2016                              Zambia       Total  16363458.0
# 181  2016                            Zimbabwe       Total  14030331.0
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             64.28648
# ...

# %%
pop2016_popsurvie.to_csv('pop2016_popsurvie.csv')

# %%
pop2016_popsurvie['politique_efficace'] = (pop2016_popsurvie['Population using at least basic drinking-water services (%)'] + pop2016_popsurvie['Population suvie (%)'])/2
pop2016_popsurvie
# Out:
#      Year                             Country Granularity  Population  \
# 0    2016                         Afghanistan       Total  35383032.0
# 1    2016                             Albania       Total   2886438.0
# 2    2016                             Algeria       Total  40551392.0
# 3    2016                              Angola       Total  28842489.0
# 4    2016                 Antigua and Barbuda       Total     94527.0
# ..    ...                                 ...         ...         ...
# 177  2016  Venezuela (Bolivarian Republic of)       Total  29851255.0
# 178  2016                            Viet Nam       Total  93640422.0
# 179  2016                               Yemen       Total  27168208.0
# 180  2016                              Zambia       Total  16363458.0
# 181  2016                            Zimbabwe       Total  14030331.0
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             64.28648
# ...

# %%
pop2016_popsurvie.drop(['Mortality rate attributed to exposure to unsafe WASH services'],axis=1,inplace=True)

# %%
pop2016_popsurvie
# Out:
#      Year                             Country Granularity  Population  \
# 0    2016                         Afghanistan       Total  35383032.0
# 1    2016                             Albania       Total   2886438.0
# 2    2016                             Algeria       Total  40551392.0
# 3    2016                              Angola       Total  28842489.0
# 4    2016                 Antigua and Barbuda       Total     94527.0
# ..    ...                                 ...         ...         ...
# 177  2016  Venezuela (Bolivarian Republic of)       Total  29851255.0
# 178  2016                            Viet Nam       Total  93640422.0
# 179  2016                               Yemen       Total  27168208.0
# 180  2016                              Zambia       Total  16363458.0
# 181  2016                            Zimbabwe       Total  14030331.0
#
#      Population using at least basic drinking-water services (%)  \
# 0                                             64.28648
# ...

# %%
pol2016_efficace = pd.merge(pol_stab2016,pop2016_popsurvie, on=['Year','Country','Granularity'], how = 'inner')
pol2016_efficace
# Out:
#                                 Country  Year  Political_Stability  \
# 0                           Afghanistan  2016                -2.67
# 1                               Albania  2016                 0.34
# 2                               Algeria  2016                -1.10
# 3                                Angola  2016                -0.32
# 4                   Antigua and Barbuda  2016                 0.88
# ..                                  ...   ...                  ...
# 176  Venezuela (Bolivarian Republic of)  2016                -1.02
# 177                            Viet Nam  2016                 0.23
# 178                               Yemen  2016                -2.79
# 179                              Zambia  2016                 0.14
# 180                            Zimbabwe  2016                -0.62
#
#     Granularity  Population  \
# 0         Total  35383032.0
# 1         Total   2886438.0
# 2         Total  40551392.0
# 3         Total  28842489.0
# ...

# %%
pol2016_efficace.to_csv('pol2016_efficace.csv')
